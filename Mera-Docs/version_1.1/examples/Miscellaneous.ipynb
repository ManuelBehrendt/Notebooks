# %% [markdown]
# # Miscellaneous

# %%
# Example-data root. Point this at your own simulation folder, or set the
# MERA_EXAMPLES environment variable; every path below is built from it.
MERA_EXAMPLES = get(ENV, "MERA_EXAMPLES", "/Volumes/FASTStorage/Simulations/Mera-Tests");

using Mera
info=getinfo(300, "$MERA_EXAMPLES/mw_L10/", verbose=false);
# Out:
# *__   __ _______ ______   _______
# |  |_|  |       |    _ | |   _   |
# |       |    ___|   | || |  |_|  |
# |       |   |___|   |_||_|       |
# |       |    ___|    __  |       |
# | ||_|| |   |___|   |  | |   _   |
# |_|   |_|_______|___|  |_|__| |__|
# Mera v1.8.0

# %% [markdown]
# ## MyArguments

# %% [markdown]
# Pass several arguments at once to a function for better readability!

# %%
# create an empty struct for arguments:
myargs = ArgumentsType()
# Out:
# ArgumentsType(missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing)

# %%
viewfields(myargs)
# Out:
# [Mera]: Fields to use as arguments in functions
# =======================================================================
# pxsize	= missing
# res	= missing
# lmax	= missing
# xrange	= missing
# yrange	= missing
# zrange	= missing
# radius	= missing
# height	= missing
# direction	= missing
# plane	= missing
# plane_ranges	= missing
# thickness	= missing
# position	= missing
# los	= missing
# up	= missing
# theta	= missing
# phi	= missing
# angle_unit	= missing
# binning	= missing
# nmax	= missing
# inclination	= missing
# azimuth	= missing
# position_angle	= missing
# axis	= missing
# center	= missing
# range_unit	= missing
# data_center	= missing
# data_center_unit	= missing
# verbose	= missing
# show_progress	= missing
# verbose_threads	= missing

# %%
# assign necessary fields:
myargs.pxsize = [100., :pc]
myargs.xrange=[-10.,10.]
myargs.yrange=[-10.,10.]
myargs.zrange=[-2.,2.]
myargs.center=[:boxcenter]
myargs.range_unit=:kpc;

# %% [markdown]
# <div class="alert alert-block alert-info"> <b>NOTE</b> All functions that hold the upper listed arguments can handle the ArgumentsType struct! </div>

# %%
gas = gethydro(info, myargs=myargs);
# Out:
# [Mera]: Get hydro data: 2026-08-03T11:38:24.326
# Key vars=(:level, :cx, :cy, :cz)
# Using var(s)=(1, 2, 3, 4, 5, 6, 7) = (:rho, :vx, :vy, :vz, :p, :scalar_00, :scalar_01)
#
# center: [0.5, 0.5, 0.5]
# ==> [24.0 [kpc] :: 24.0 [kpc] :: 24.0 [kpc]]
#
# domain:
# xmin::xmax: 0.2916667 :: 0.7083333  	==> 14.0 [kpc] :: 34.0 [kpc]
# ymin::ymax: 0.2916667 :: 0.7083333  	==> 14.0 [kpc] :: 34.0 [kpc]
# zmin::zmax: 0.4583333 :: 0.5416667  	==> 22.0 [kpc] :: 26.0 [kpc]
#
# 📊 Processing Configuration:
#    Total CPU files available: 640
#    Files to be processed: 640
#    Compute threads: 4
#    GC threads: 4
# Processing files:   0%|                                                  |  ETA: N/A (  N/A  s/it)
# Processing files:   3%|█▋                                                |  ETA: 0:00:34 (55.30 ms/it)
# Processing files:   4%|█▉                                                |  ETA: 0:00:33 (53.24 ms/it)
# Processing files:   4%|██▏                                               |  ETA: 0:00:32 (51.62 ms/it)
# Processing files:   5%|██▍                                               |  ETA: 0:00:32 (51.94 ms/it)
# Processing files:   5%|██▊                                               |  ETA: 0:00:29 (47.70 ms/it)
# Processing files:   6%|███▏                                              |  ETA: 0:00:27 (44.75 ms/it)
# Processing files:   7%|███▌                                              |  ETA: 0:00:26 (44.37 ms/it)
# Processing files:   9%|████▎                                             |  ETA: 0:00:24 (40.70 ms/it)
# Processing files:   9%|████▊                                             |  ETA: 0:00:23 (40.02 ms/it)
# Processing files:  11%|█████▎                                            |  ETA: 0:00:23 (39.49 ms/it)
# Processing files:  13%|██████▍                                           |  ETA: 0:00:21 (36.96 ms/it)
# Processing files:  13%|██████▊                                           |  ETA: 0:00:20 (36.42 ms/it)
# Processing files:  14%|███████                                           |  ETA: 0:00:20 (36.01 ms/it)
# Processing files:  15%|███████▍                                          |  ETA: 0:00:19 (35.60 ms/it)
# Processing files:  15%|███████▊                                          |  ETA: 0:00:19 (34.83 ms/it)
# Processing files:  16%|████████                                          |  ETA: 0:00:19 (35.07 ms/it)
# Processing files:  17%|████████▍                                         |  ETA: 0:00:19 (34.76 ms/it)
# Processing files:  17%|████████▋                                         |  ETA: 0:00:18 (34.42 ms/it)
# Processing files:  18%|█████████                                         |  ETA: 0:00:18 (34.18 ms/it)
# Processing files:  19%|█████████▎                                        |  ETA: 0:00:18 (34.23 ms/it)
# Processing files:  19%|█████████▊                                        |  ETA: 0:00:18 (33.92 ms/it)
# Processing files:  20%|██████████▏                                       |  ETA: 0:00:17 (33.42 ms/it)
# Processing files:  21%|██████████▋                                       |  ETA: 0:00:17 (32.86 ms/it)
# Processing files:  22%|███████████▎                                      |  ETA: 0:00:16 (32.20 ms/it)
# Processing files:  23%|███████████▌                                      |  ETA: 0:00:16 (32.25 ms/it)
# Processing files:  25%|████████████▋                                     |  ETA: 0:00:15 (31.15 ms/it)
# Processing files:  26%|█████████████▏                                    |  ETA: 0:00:15 (30.98 ms/it)
# Processing files:  27%|█████████████▌                                    |  ETA: 0:00:15 (31.01 ms/it)
# Processing files:  29%|██████████████▌                                   |  ETA: 0:00:14 (30.48 ms/it)
# Processing files:  30%|██████████████▊                                   |  ETA: 0:00:14 (30.63 ms/it)
# Processing files:  31%|███████████████▎                                  |  ETA: 0:00:13 (30.40 ms/it)
# Processing files:  32%|███████████████▊                                  |  ETA: 0:00:13 (30.01 ms/it)
# Processing files:  32%|████████████████▎                                 |  ETA: 0:00:13 (30.04 ms/it)
# Processing files:  34%|█████████████████▎                                |  ETA: 0:00:13 (29.94 ms/it)
# Processing files:  35%|█████████████████▋                                |  ETA: 0:00:12 (29.66 ms/it)
# Processing files:  36%|██████████████████▏                               |  ETA: 0:00:12 (29.49 ms/it)
# Processing files:  37%|██████████████████▌                               |  ETA: 0:00:12 (29.56 ms/it)
# Processing files:  39%|███████████████████▎                              |  ETA: 0:00:12 (29.40 ms/it)
# Processing files:  39%|███████████████████▊                              |  ETA: 0:00:11 (29.39 ms/it)
# Processing files:  40%|████████████████████▏                             |  ETA: 0:00:11 (29.34 ms/it)
# Processing files:  41%|████████████████████▍                             |  ETA: 0:00:11 (29.33 ms/it)
# Processing files:  41%|████████████████████▊                             |  ETA: 0:00:11 (29.35 ms/it)
# Processing files:  42%|█████████████████████                             |  ETA: 0:00:11 (29.29 ms/it)
# Processing files:  43%|█████████████████████▍                            |  ETA: 0:00:11 (29.33 ms/it)
# Processing files:  43%|█████████████████████▋                            |  ETA: 0:00:11 (29.32 ms/it)
# Processing files:  44%|██████████████████████                            |  ETA: 0:00:11 (29.29 ms/it)
# Processing files:  45%|██████████████████████▎                           |  ETA: 0:00:10 (29.38 ms/it)
# Processing files:  45%|██████████████████████▌                           |  ETA: 0:00:10 (29.56 ms/it)
# Processing files:  46%|██████████████████████▊                           |  ETA: 0:00:10 (29.82 ms/it)
# Processing files:  46%|███████████████████████▏                          |  ETA: 0:00:10 (29.81 ms/it)
# Processing files:  47%|███████████████████████▍                          |  ETA: 0:00:10 (29.97 ms/it)
# Processing files:  48%|███████████████████████▉                          |  ETA: 0:00:10 (30.10 ms/it)
# Processing files:  48%|████████████████████████                          |  ETA: 0:00:10 (30.26 ms/it)
# Processing files:  49%|████████████████████████▍                         |  ETA: 0:00:10 (30.46 ms/it)
# Processing files:  49%|████████████████████████▊                         |  ETA: 0:00:10 (30.66 ms/it)
# Processing files:  50%|█████████████████████████▏                        |  ETA: 0:00:10 (30.72 ms/it)
# Processing files:  51%|█████████████████████████▍                        |  ETA: 0:00:10 (30.79 ms/it)
# Processing files:  52%|█████████████████████████▊                        |  ETA: 0:00:10 (30.66 ms/it)
# Processing files:  52%|██████████████████████████▏                       |  ETA: 0:00:09 (30.80 ms/it)
# Processing files:  53%|██████████████████████████▍                       |  ETA: 0:00:09 (30.93 ms/it)
# Processing files:  53%|██████████████████████████▊                       |  ETA: 0:00:09 (30.99 ms/it)
# Processing files:  55%|███████████████████████████▎                      |  ETA: 0:00:09 (30.83 ms/it)
# Processing files:  55%|███████████████████████████▋                      |  ETA: 0:00:09 (30.84 ms/it)
# Processing files:  56%|███████████████████████████▉                      |  ETA: 0:00:09 (30.79 ms/it)
# Processing files:  56%|████████████████████████████▎                     |  ETA: 0:00:09 (30.73 ms/it)
# Processing files:  57%|████████████████████████████▌                     |  ETA: 0:00:08 (30.69 ms/it)
# Processing files:  58%|████████████████████████████▉                     |  ETA: 0:00:08 (30.65 ms/it)
# Processing files:  58%|█████████████████████████████▎                    |  ETA: 0:00:08 (30.57 ms/it)
# Processing files:  59%|█████████████████████████████▌                    |  ETA: 0:00:08 (30.52 ms/it)
# Processing files:  60%|█████████████████████████████▉                    |  ETA: 0:00:08 (30.39 ms/it)
# Processing files:  61%|██████████████████████████████▎                   |  ETA: 0:00:08 (30.29 ms/it)
# Processing files:  61%|██████████████████████████████▊                   |  ETA: 0:00:07 (30.33 ms/it)
# Processing files:  64%|███████████████████████████████▊                  |  ETA: 0:00:07 (30.09 ms/it)
# Processing files:  64%|████████████████████████████████▎                 |  ETA: 0:00:07 (29.99 ms/it)
# Processing files:  65%|████████████████████████████████▋                 |  ETA: 0:00:07 (29.98 ms/it)
# Processing files:  67%|█████████████████████████████████▍                |  ETA: 0:00:06 (29.73 ms/it)
# Processing files:  68%|█████████████████████████████████▉                |  ETA: 0:00:06 (29.65 ms/it)
# Processing files:  69%|██████████████████████████████████▎               |  ETA: 0:00:06 (29.50 ms/it)
# Processing files:  69%|██████████████████████████████████▊               |  ETA: 0:00:06 (29.48 ms/it)
# Processing files:  70%|███████████████████████████████████▏              |  ETA: 0:00:06 (29.48 ms/it)
# Processing files:  72%|███████████████████████████████████▉              |  ETA: 0:00:05 (29.28 ms/it)
# Processing files:  73%|████████████████████████████████████▍             |  ETA: 0:00:05 (29.13 ms/it)
# Processing files:  74%|████████████████████████████████████▊             |  ETA: 0:00:05 (29.12 ms/it)
# Processing files:  75%|█████████████████████████████████████▎            |  ETA: 0:00:05 (29.05 ms/it)
# Processing files:  76%|█████████████████████████████████████▉            |  ETA: 0:00:04 (28.92 ms/it)
# Processing files:  77%|██████████████████████████████████████▌           |  ETA: 0:00:04 (28.72 ms/it)
# Processing files:  78%|███████████████████████████████████████           |  ETA: 0:00:04 (28.64 ms/it)
# Processing files:  79%|███████████████████████████████████████▍          |  ETA: 0:00:04 (28.59 ms/it)
# Processing files:  79%|███████████████████████████████████████▊          |  ETA: 0:00:04 (28.58 ms/it)
# Processing files:  80%|████████████████████████████████████████          |  ETA: 0:00:04 (28.62 ms/it)
# Processing files:  82%|████████████████████████████████████████▊         |  ETA: 0:00:03 (28.63 ms/it)
# Processing files:  82%|█████████████████████████████████████████▏        |  ETA: 0:00:03 (28.56 ms/it)
# Processing files:  83%|█████████████████████████████████████████▌        |  ETA: 0:00:03 (28.53 ms/it)
# Processing files:  84%|█████████████████████████████████████████▉        |  ETA: 0:00:03 (28.55 ms/it)
# Processing files:  84%|██████████████████████████████████████████▏       |  ETA: 0:00:03 (28.62 ms/it)
# Processing files:  87%|███████████████████████████████████████████▋      |  ETA: 0:00:02 (28.44 ms/it)
# Processing files:  88%|███████████████████████████████████████████▉      |  ETA: 0:00:02 (28.42 ms/it)
# Processing files:  89%|████████████████████████████████████████████▎     |  ETA: 0:00:02 (28.41 ms/it)
# Processing files:  90%|████████████████████████████████████████████▊     |  ETA: 0:00:02 (28.32 ms/it)
# Processing files:  90%|█████████████████████████████████████████████▏    |  ETA: 0:00:02 (28.32 ms/it)
# Processing files:  91%|█████████████████████████████████████████████▌    |  ETA: 0:00:02 (28.31 ms/it)
# Processing files:  92%|█████████████████████████████████████████████▉    |  ETA: 0:00:01 (28.29 ms/it)
# Processing files:  92%|██████████████████████████████████████████████▎   |  ETA: 0:00:01 (28.24 ms/it)
# Processing files:  93%|██████████████████████████████████████████████▌   |  ETA: 0:00:01 (28.24 ms/it)
# Processing files:  94%|██████████████████████████████████████████████▊   |  ETA: 0:00:01 (28.33 ms/it)
# Processing files:  94%|███████████████████████████████████████████████▏  |  ETA: 0:00:01 (28.32 ms/it)
# Processing files:  95%|███████████████████████████████████████████████▍  |  ETA: 0:00:01 (28.39 ms/it)
# Processing files:  95%|███████████████████████████████████████████████▋  |  ETA: 0:00:01 (28.45 ms/it)
# Processing files:  96%|███████████████████████████████████████████████▉  |  ETA: 0:00:01 (28.53 ms/it)
# Processing files:  96%|████████████████████████████████████████████████▎ |  ETA: 0:00:01 (28.61 ms/it)
# Processing files:  97%|████████████████████████████████████████████████▌ |  ETA: 0:00:01 (28.70 ms/it)
# Processing files:  97%|████████████████████████████████████████████████▋ |  ETA: 0:00:01 (28.87 ms/it)
# Processing files:  98%|█████████████████████████████████████████████████ |  ETA: 0:00:00 (28.89 ms/it)
# Processing files:  99%|█████████████████████████████████████████████████▎|  ETA: 0:00:00 (29.01 ms/it)
# Processing files: 100%|██████████████████████████████████████████████████| Time: 0:00:18 (29.02 ms/it)
# ✓ File processing complete! Combining results...
# ✓ Data combination complete!
# Final data size: 6914359 cells, 7 variables
# Creating Table from 6914359 cells with max 4 threads...
#   Threading: 4 threads for 11 columns
#   Max threads requested: 4
#   Available threads: 4
#   Using parallel processing with 4 threads
#   Creating IndexedTable with 11 columns...
# ✓ Table created in 9.684 seconds
# Memory used for data table :580.2772397994995
#  MB
# -------------------------------------------------------

# %%
part = getparticles(info, myargs=myargs);
# Out:
# [Mera]: Get particle data: 2026-08-03T11:38:57.004
# Using threaded processing with 4 threads
# Key vars=(:level, :x, :y, :z, :id, :family, :tag)
# Using var(s)=(1, 2, 3, 4, 7) = (:vx, :vy, :vz, :mass, :birth)
#
# center: [0.5, 0.5, 0.5] ==> [24.0 [kpc] :: 24.0 [kpc] :: 24.0 [kpc]]
#
# domain:
# xmin::xmax: 0.2916667 :: 0.7083333  	==> 14.0 [kpc] :: 34.0 [kpc]
# ymin::ymax: 0.2916667 :: 0.7083333  	==> 14.0 [kpc] :: 34.0 [kpc]
# zmin::zmax: 0.4583333 :: 0.5416667  	==> 22.0 [kpc] :: 26.0 [kpc]
#
# Processing 640 CPU files using 4 threads
# Mode: Threaded processing
# Combining results from 4 thread(s)...
# Found 5.368130e+05 particles
# Memory used for data table :
# 37.885175704956055 MB
# -------------------------------------------------------

# %%
p = projection(gas, :sd, :Msun_pc2, myargs=myargs);
# Out:
# [Mera]: 2026-08-03T11:39:06.827
# center: [0.5, 0.5, 0.5] ==> [24.0 [kpc] :: 24.0 [kpc] :: 24.0 [kpc]]
#
# domain:
# xmin::xmax: 0.2916667 :: 0.7083333  	==> 14.0 [kpc] :: 34.0 [kpc]
# ymin::ymax: 0.2916667 :: 0.7083333  	==> 14.0 [kpc] :: 34.0 [kpc]
# zmin::zmax: 0.4583333 :: 0.5416667  	==> 22.0 [kpc] :: 26.0 [kpc]
#
# Selected var(s)=(:sd,)
# Weighting      = :mass
#
# Effective resolution: 481^2
# Map size: 201 x 201
# Pixel size: 99.792 [pc]
# Simulation min.: 46.875 [pc]
#
# Available threads: 4
# Requested max_threads: 4
# Variables: 1 (sd)
# Processing mode: Sequential (single thread)

# %%
# add more args for silent screen:
myargs.verbose=false
myargs.show_progress=false;

# %%
gas = gethydro(info, myargs=myargs);

# %%
part = getparticles(info, myargs=myargs);

# %%
p = projection(gas, :sd, :Msun_pc2, myargs=myargs);

# %% [markdown]
# ## Verbose & Progressbar Switch
# Master switch to toggle the verbose mode and progress bar for all functions:

# %%
# current status
# "nothing" allows the functions to use the passed argument: 
# verbose=false/true
verbose()
# Out:
# verbose_mode: nothing

# %%
# switch off verbose mode globally:
verbose(false)
# Out:
# false

# %%
# check
gas = gethydro(info);
# Out:
# Processing files:   0%|▏                                                 |  ETA: 0:00:44 (69.61 ms/it)
# Processing files:   1%|▌                                                 |  ETA: 0:00:31 (48.40 ms/it)
# Processing files:   3%|█▊                                                |  ETA: 0:00:26 (41.73 ms/it)
# Processing files:   5%|██▊                                               |  ETA: 0:00:23 (38.79 ms/it)
# Processing files:   6%|███                                               |  ETA: 0:00:23 (37.50 ms/it)
# Processing files:   7%|███▍                                              |  ETA: 0:00:22 (36.41 ms/it)
# Processing files:   8%|███▊                                              |  ETA: 0:00:21 (35.22 ms/it)
# Processing files:   8%|████▎                                             |  ETA: 0:00:19 (33.26 ms/it)
# Processing files:   9%|████▊                                             |  ETA: 0:00:19 (32.16 ms/it)
# Processing files:  10%|█████▏                                            |  ETA: 0:00:18 (31.58 ms/it)
# Processing files:  11%|█████▍                                            |  ETA: 0:00:18 (31.36 ms/it)
# Processing files:  11%|█████▊                                            |  ETA: 0:00:18 (31.07 ms/it)
# Processing files:  13%|██████▍                                           |  ETA: 0:00:16 (29.33 ms/it)
# Processing files:  14%|███████                                           |  ETA: 0:00:15 (27.52 ms/it)
# Processing files:  15%|███████▊                                          |  ETA: 0:00:14 (26.08 ms/it)
# Processing files:  17%|████████▌                                         |  ETA: 0:00:13 (24.96 ms/it)
# Processing files:  18%|█████████▏                                        |  ETA: 0:00:13 (24.03 ms/it)
# Processing files:  19%|█████████▊                                        |  ETA: 0:00:12 (23.84 ms/it)
# Processing files:  21%|██████████▌                                       |  ETA: 0:00:12 (22.90 ms/it)
# Processing files:  23%|███████████▌                                      |  ETA: 0:00:11 (21.41 ms/it)
# Processing files:  25%|████████████▋                                     |  ETA: 0:00:10 (20.46 ms/it)
# Processing files:  27%|█████████████▌                                    |  ETA: 0:00:09 (19.92 ms/it)
# Processing files:  28%|██████████████▏                                   |  ETA: 0:00:09 (19.74 ms/it)
# Processing files:  30%|███████████████                                   |  ETA: 0:00:09 (19.16 ms/it)
# Processing files:  32%|███████████████▊                                  |  ETA: 0:00:08 (18.77 ms/it)
# Processing files:  33%|████████████████▌                                 |  ETA: 0:00:08 (18.52 ms/it)
# Processing files:  34%|█████████████████▎                                |  ETA: 0:00:08 (18.22 ms/it)
# Processing files:  36%|█████████████████▊                                |  ETA: 0:00:07 (18.10 ms/it)
# Processing files:  37%|██████████████████▋                               |  ETA: 0:00:07 (17.90 ms/it)
# Processing files:  38%|███████████████████▎                              |  ETA: 0:00:07 (17.91 ms/it)
# Processing files:  40%|███████████████████▉                              |  ETA: 0:00:07 (17.77 ms/it)
# Processing files:  41%|████████████████████▊                             |  ETA: 0:00:07 (17.53 ms/it)
# Processing files:  43%|█████████████████████▍                            |  ETA: 0:00:07 (17.80 ms/it)
# Processing files:  44%|█████████████████████▊                            |  ETA: 0:00:06 (17.87 ms/it)
# Processing files:  44%|██████████████████████▏                           |  ETA: 0:00:06 (18.04 ms/it)
# Processing files:  45%|██████████████████████▍                           |  ETA: 0:00:06 (18.35 ms/it)
# Processing files:  45%|██████████████████████▋                           |  ETA: 0:00:07 (18.63 ms/it)
# Processing files:  46%|███████████████████████                           |  ETA: 0:00:06 (18.73 ms/it)
# Processing files:  47%|███████████████████████▎                          |  ETA: 0:00:06 (18.89 ms/it)
# Processing files:  47%|███████████████████████▋                          |  ETA: 0:00:06 (19.04 ms/it)
# Processing files:  48%|███████████████████████▉                          |  ETA: 0:00:06 (19.19 ms/it)
# Processing files:  48%|████████████████████████                          |  ETA: 0:00:06 (19.46 ms/it)
# Processing files:  49%|████████████████████████▌                         |  ETA: 0:00:06 (19.63 ms/it)
# Processing files:  50%|████████████████████████▉                         |  ETA: 0:00:06 (19.94 ms/it)
# Processing files:  50%|█████████████████████████                         |  ETA: 0:00:06 (20.15 ms/it)
# Processing files:  51%|█████████████████████████▍                        |  ETA: 0:00:06 (20.36 ms/it)
# Processing files:  51%|█████████████████████████▊                        |  ETA: 0:00:06 (20.45 ms/it)
# Processing files:  52%|██████████████████████████                        |  ETA: 0:00:06 (20.74 ms/it)
# Processing files:  53%|██████████████████████████▍                       |  ETA: 0:00:06 (20.89 ms/it)
# Processing files:  53%|██████████████████████████▋                       |  ETA: 0:00:06 (21.12 ms/it)
# Processing files:  54%|███████████████████████████▎                      |  ETA: 0:00:06 (21.51 ms/it)
# Processing files:  55%|███████████████████████████▋                      |  ETA: 0:00:06 (21.61 ms/it)
# Processing files:  56%|████████████████████████████                      |  ETA: 0:00:06 (21.88 ms/it)
# Processing files:  57%|████████████████████████████▎                     |  ETA: 0:00:06 (22.03 ms/it)
# Processing files:  57%|████████████████████████████▌                     |  ETA: 0:00:06 (22.17 ms/it)
# Processing files:  58%|█████████████████████████████▎                    |  ETA: 0:00:06 (22.17 ms/it)
# Processing files:  59%|█████████████████████████████▋                    |  ETA: 0:00:06 (22.41 ms/it)
# Processing files:  60%|█████████████████████████████▉                    |  ETA: 0:00:06 (22.46 ms/it)
# Processing files:  60%|██████████████████████████████▏                   |  ETA: 0:00:06 (22.64 ms/it)
# Processing files:  62%|██████████████████████████████▊                   |  ETA: 0:00:06 (23.13 ms/it)
# Processing files:  62%|███████████████████████████████▎                  |  ETA: 0:00:06 (23.07 ms/it)
# Processing files:  63%|███████████████████████████████▊                  |  ETA: 0:00:05 (23.02 ms/it)
# Processing files:  64%|████████████████████████████████▏                 |  ETA: 0:00:05 (23.09 ms/it)
# Processing files:  65%|████████████████████████████████▋                 |  ETA: 0:00:05 (23.05 ms/it)
# Processing files:  66%|█████████████████████████████████                 |  ETA: 0:00:05 (23.10 ms/it)
# Processing files:  67%|█████████████████████████████████▋                |  ETA: 0:00:05 (23.01 ms/it)
# Processing files:  68%|██████████████████████████████████                |  ETA: 0:00:05 (22.99 ms/it)
# Processing files:  69%|██████████████████████████████████▌               |  ETA: 0:00:05 (22.98 ms/it)
# Processing files:  70%|██████████████████████████████████▉               |  ETA: 0:00:04 (23.06 ms/it)
# Processing files:  71%|███████████████████████████████████▌              |  ETA: 0:00:04 (23.16 ms/it)
# Processing files:  72%|███████████████████████████████████▊              |  ETA: 0:00:04 (23.21 ms/it)
# Processing files:  72%|████████████████████████████████████▏             |  ETA: 0:00:04 (23.25 ms/it)
# Processing files:  73%|████████████████████████████████████▌             |  ETA: 0:00:04 (23.19 ms/it)
# Processing files:  74%|█████████████████████████████████████             |  ETA: 0:00:04 (23.29 ms/it)
# Processing files:  75%|█████████████████████████████████████▌            |  ETA: 0:00:04 (23.24 ms/it)
# Processing files:  76%|█████████████████████████████████████▉            |  ETA: 0:00:04 (23.29 ms/it)
# Processing files:  77%|██████████████████████████████████████▎           |  ETA: 0:00:03 (23.26 ms/it)
# Processing files:  77%|██████████████████████████████████████▋           |  ETA: 0:00:03 (23.36 ms/it)
# Processing files:  79%|███████████████████████████████████████▌          |  ETA: 0:00:03 (23.31 ms/it)
# Processing files:  80%|███████████████████████████████████████▉          |  ETA: 0:00:03 (23.32 ms/it)
# Processing files:  80%|████████████████████████████████████████▎         |  ETA: 0:00:03 (23.43 ms/it)
# Processing files:  81%|████████████████████████████████████████▌         |  ETA: 0:00:03 (23.44 ms/it)
# Processing files:  82%|█████████████████████████████████████████         |  ETA: 0:00:03 (23.38 ms/it)
# Processing files:  83%|█████████████████████████████████████████▍        |  ETA: 0:00:03 (23.42 ms/it)
# Processing files:  83%|█████████████████████████████████████████▊        |  ETA: 0:00:02 (23.45 ms/it)
# Processing files:  85%|██████████████████████████████████████████▎       |  ETA: 0:00:02 (23.37 ms/it)
# Processing files:  85%|██████████████████████████████████████████▊       |  ETA: 0:00:02 (23.33 ms/it)
# Processing files:  86%|███████████████████████████████████████████▏      |  ETA: 0:00:02 (23.36 ms/it)
# Processing files:  87%|███████████████████████████████████████████▌      |  ETA: 0:00:02 (23.38 ms/it)
# Processing files:  88%|███████████████████████████████████████████▉      |  ETA: 0:00:02 (23.37 ms/it)
# Processing files:  88%|████████████████████████████████████████████▎     |  ETA: 0:00:02 (23.38 ms/it)
# Processing files:  89%|████████████████████████████████████████████▌     |  ETA: 0:00:02 (23.45 ms/it)
# Processing files:  90%|█████████████████████████████████████████████▏    |  ETA: 0:00:01 (23.47 ms/it)
# Processing files:  91%|█████████████████████████████████████████████▍    |  ETA: 0:00:01 (23.54 ms/it)
# Processing files:  94%|███████████████████████████████████████████████   |  ETA: 0:00:01 (23.65 ms/it)
# Processing files:  95%|███████████████████████████████████████████████▍  |  ETA: 0:00:01 (23.71 ms/it)
# Processing files:  96%|███████████████████████████████████████████████▊  |  ETA: 0:00:01 (23.69 ms/it)
# Processing files:  96%|████████████████████████████████████████████████▎ |  ETA: 0:00:01 (23.75 ms/it)
# Processing files:  97%|████████████████████████████████████████████████▌ |  ETA: 0:00:00 (23.77 ms/it)
# Processing files:  98%|████████████████████████████████████████████████▉ |  ETA: 0:00:00 (23.82 ms/it)
# Processing files:  98%|█████████████████████████████████████████████████▏|  ETA: 0:00:00 (23.91 ms/it)
# Processing files:  99%|█████████████████████████████████████████████████▌|  ETA: 0:00:00 (23.97 ms/it)
# Processing files:  99%|█████████████████████████████████████████████████▊|  ETA: 0:00:00 (24.03 ms/it)
# Processing files:  99%|█████████████████████████████████████████████████▉|  ETA: 0:00:00 (24.12 ms/it)
# Processing files: 100%|██████████████████████████████████████████████████| Time: 0:00:15 (24.08 ms/it)
# ✓ File processing complete! Combining results...

# %%
# switch on verbose mode globally:
# the passed argument verbose=false/true to the individual
# functions is ignored.
verbose(true)
# Out:
# true

# %%
gas = gethydro(info);
# Out:
# [Mera]: Get hydro data: 2026-08-03T11:40:32.648
#
# Key vars=(:level, :cx, :cy, :cz)
# Using var(s)=(1, 2, 3, 4, 5, 6, 7) = (:rho, :vx, :vy, :vz, :p, :scalar_00, :scalar_01)
#
# domain:
# xmin::xmax: 0.0 :: 1.0  	==> 0.0 [kpc] :: 48.0 [kpc]
# ymin::ymax: 0.0 :: 1.0  	==> 0.0 [kpc] :: 48.0 [kpc]
# zmin::zmax: 0.0 :: 1.0  	==> 0.0 [kpc] :: 48.0 [kpc]
#
# 📊 Processing Configuration:
#    Total CPU files available: 640
#    Files to be processed: 640
#    Compute threads: 4
#    GC threads: 4
# Processing files:   0%|                                                  |  ETA: N/A (  N/A  s/it)
# Processing files:   1%|▍                                                 |  ETA: 0:00:38 (60.01 ms/it)
# Processing files:   1%|▊                                                 |  ETA: 0:00:29 (46.34 ms/it)
# Processing files:   2%|█                                                 |  ETA: 0:00:28 (43.91 ms/it)
# Processing files:   2%|█▎                                                |  ETA: 0:00:27 (43.87 ms/it)
# Processing files:   4%|█▊                                                |  ETA: 0:00:24 (38.56 ms/it)
# Processing files:   4%|██▏                                               |  ETA: 0:00:23 (37.51 ms/it)
# Processing files:   5%|██▍                                               |  ETA: 0:00:23 (38.25 ms/it)
# Processing files:   5%|██▋                                               |  ETA: 0:00:23 (38.36 ms/it)
# Processing files:   6%|███                                               |  ETA: 0:00:22 (37.10 ms/it)
# Processing files:   7%|███▎                                              |  ETA: 0:00:22 (35.97 ms/it)
# Processing files:   7%|███▋                                              |  ETA: 0:00:21 (35.11 ms/it)
# Processing files:   8%|████▏                                             |  ETA: 0:00:20 (33.35 ms/it)
# Processing files:   9%|████▋                                             |  ETA: 0:00:19 (32.16 ms/it)
# Processing files:  10%|█████                                             |  ETA: 0:00:18 (31.53 ms/it)
# Processing files:  11%|█████▍                                            |  ETA: 0:00:18 (30.98 ms/it)
# Processing files:  12%|█████▉                                            |  ETA: 0:00:17 (30.60 ms/it)
# Processing files:  13%|██████▋                                           |  ETA: 0:00:16 (29.21 ms/it)
# Processing files:  14%|███████▏                                          |  ETA: 0:00:16 (28.96 ms/it)
# Processing files:  16%|███████▊                                          |  ETA: 0:00:15 (28.38 ms/it)
# Processing files:  17%|████████▎                                         |  ETA: 0:00:15 (27.87 ms/it)
# Processing files:  17%|████████▋                                         |  ETA: 0:00:15 (27.78 ms/it)
# Processing files:  18%|████████▉                                         |  ETA: 0:00:15 (27.93 ms/it)
# Processing files:  20%|██████████▎                                       |  ETA: 0:00:14 (26.90 ms/it)
# Processing files:  22%|██████████▊                                       |  ETA: 0:00:13 (26.60 ms/it)
# Processing files:  22%|███████████▎                                      |  ETA: 0:00:13 (26.27 ms/it)
# Processing files:  23%|███████████▊                                      |  ETA: 0:00:13 (26.14 ms/it)
# Processing files:  25%|████████████▍                                     |  ETA: 0:00:12 (25.81 ms/it)
# Processing files:  26%|█████████████                                     |  ETA: 0:00:12 (25.43 ms/it)
# Processing files:  27%|█████████████▌                                    |  ETA: 0:00:12 (25.48 ms/it)
# Processing files:  28%|█████████████▉                                    |  ETA: 0:00:12 (25.37 ms/it)
# Processing files:  29%|██████████████▍                                   |  ETA: 0:00:11 (25.10 ms/it)
# Processing files:  30%|██████████████▉                                   |  ETA: 0:00:11 (25.09 ms/it)
# Processing files:  31%|███████████████▍                                  |  ETA: 0:00:11 (24.86 ms/it)
# Processing files:  32%|███████████████▊                                  |  ETA: 0:00:11 (24.83 ms/it)
# Processing files:  33%|████████████████▍                                 |  ETA: 0:00:11 (24.79 ms/it)
# Processing files:  35%|█████████████████▎                                |  ETA: 0:00:10 (24.90 ms/it)
# Processing files:  35%|█████████████████▊                                |  ETA: 0:00:10 (24.70 ms/it)
# Processing files:  36%|██████████████████▏                               |  ETA: 0:00:10 (24.61 ms/it)
# Processing files:  37%|██████████████████▌                               |  ETA: 0:00:10 (24.81 ms/it)
# Processing files:  38%|███████████████████                               |  ETA: 0:00:10 (24.85 ms/it)
# Processing files:  39%|███████████████████▌                              |  ETA: 0:00:10 (24.76 ms/it)
# Processing files:  40%|███████████████████▉                              |  ETA: 0:00:10 (24.74 ms/it)
# Processing files:  40%|████████████████████▏                             |  ETA: 0:00:09 (24.75 ms/it)
# Processing files:  41%|████████████████████▌                             |  ETA: 0:00:09 (24.78 ms/it)
# Processing files:  42%|████████████████████▊                             |  ETA: 0:00:09 (24.86 ms/it)
# Processing files:  42%|█████████████████████▏                            |  ETA: 0:00:09 (24.87 ms/it)
# Processing files:  43%|█████████████████████▍                            |  ETA: 0:00:09 (25.06 ms/it)
# Processing files:  43%|█████████████████████▌                            |  ETA: 0:00:09 (25.19 ms/it)
# Processing files:  46%|███████████████████████                           |  ETA: 0:00:09 (25.88 ms/it)
# Processing files:  46%|███████████████████████▎                          |  ETA: 0:00:09 (26.10 ms/it)
# Processing files:  47%|███████████████████████▍                          |  ETA: 0:00:09 (26.30 ms/it)
# Processing files:  48%|████████████████████████                          |  ETA: 0:00:09 (26.87 ms/it)
# Processing files:  49%|████████████████████████▋                         |  ETA: 0:00:09 (27.22 ms/it)
# Processing files:  51%|█████████████████████████▎                        |  ETA: 0:00:09 (27.50 ms/it)
# Processing files:  52%|█████████████████████████▊                        |  ETA: 0:00:09 (27.60 ms/it)
# Processing files:  52%|██████████████████████████                        |  ETA: 0:00:09 (27.73 ms/it)
# Processing files:  53%|██████████████████████████▌                       |  ETA: 0:00:08 (27.91 ms/it)
# Processing files:  53%|██████████████████████████▊                       |  ETA: 0:00:08 (28.34 ms/it)
# Processing files:  54%|███████████████████████████▎                      |  ETA: 0:00:08 (28.33 ms/it)
# Processing files:  55%|███████████████████████████▌                      |  ETA: 0:00:08 (28.38 ms/it)
# Processing files:  56%|███████████████████████████▊                      |  ETA: 0:00:08 (28.45 ms/it)
# Processing files:  56%|████████████████████████████                      |  ETA: 0:00:08 (28.52 ms/it)
# Processing files:  57%|████████████████████████████▌                     |  ETA: 0:00:08 (28.51 ms/it)
# Processing files:  58%|████████████████████████████▊                     |  ETA: 0:00:08 (28.48 ms/it)
# Processing files:  58%|█████████████████████████████                     |  ETA: 0:00:08 (28.46 ms/it)
# Processing files:  59%|█████████████████████████████▌                    |  ETA: 0:00:07 (28.42 ms/it)
# Processing files:  60%|█████████████████████████████▉                    |  ETA: 0:00:07 (28.42 ms/it)
# Processing files:  61%|██████████████████████████████▎                   |  ETA: 0:00:07 (28.36 ms/it)
# Processing files:  61%|██████████████████████████████▋                   |  ETA: 0:00:07 (28.34 ms/it)
# Processing files:  62%|███████████████████████████████                   |  ETA: 0:00:07 (28.25 ms/it)
# Processing files:  63%|███████████████████████████████▍                  |  ETA: 0:00:07 (28.27 ms/it)
# Processing files:  63%|███████████████████████████████▋                  |  ETA: 0:00:07 (28.37 ms/it)
# Processing files:  64%|████████████████████████████████                  |  ETA: 0:00:07 (28.33 ms/it)
# Processing files:  65%|████████████████████████████████▍                 |  ETA: 0:00:06 (28.35 ms/it)
# Processing files:  65%|████████████████████████████████▋                 |  ETA: 0:00:06 (28.34 ms/it)
# Processing files:  66%|█████████████████████████████████▏                |  ETA: 0:00:06 (28.25 ms/it)
# Processing files:  67%|█████████████████████████████████▋                |  ETA: 0:00:06 (28.10 ms/it)
# Processing files:  68%|██████████████████████████████████                |  ETA: 0:00:06 (28.06 ms/it)
# Processing files:  69%|██████████████████████████████████▋               |  ETA: 0:00:06 (27.96 ms/it)
# Processing files:  70%|███████████████████████████████████▏              |  ETA: 0:00:05 (27.82 ms/it)
# Processing files:  71%|███████████████████████████████████▌              |  ETA: 0:00:05 (27.78 ms/it)
# Processing files:  72%|████████████████████████████████████▏             |  ETA: 0:00:05 (27.70 ms/it)
# Processing files:  75%|█████████████████████████████████████▋            |  ETA: 0:00:04 (27.32 ms/it)
# Processing files:  76%|██████████████████████████████████████▎           |  ETA: 0:00:04 (27.23 ms/it)
# Processing files:  78%|██████████████████████████████████████▊           |  ETA: 0:00:04 (27.07 ms/it)
# Processing files:  78%|███████████████████████████████████████▎          |  ETA: 0:00:04 (27.03 ms/it)
# Processing files:  79%|███████████████████████████████████████▊          |  ETA: 0:00:04 (27.08 ms/it)
# Processing files:  81%|████████████████████████████████████████▌         |  ETA: 0:00:03 (26.93 ms/it)
# Processing files:  82%|█████████████████████████████████████████         |  ETA: 0:00:03 (26.95 ms/it)
# Processing files:  83%|█████████████████████████████████████████▌        |  ETA: 0:00:03 (26.85 ms/it)
# Processing files:  84%|█████████████████████████████████████████▉        |  ETA: 0:00:03 (26.85 ms/it)
# Processing files:  85%|██████████████████████████████████████████▍       |  ETA: 0:00:03 (26.77 ms/it)
# Processing files:  85%|██████████████████████████████████████████▊       |  ETA: 0:00:02 (26.78 ms/it)
# Processing files:  86%|███████████████████████████████████████████▏      |  ETA: 0:00:02 (26.72 ms/it)
# Processing files:  87%|███████████████████████████████████████████▋      |  ETA: 0:00:02 (26.68 ms/it)
# Processing files:  88%|████████████████████████████████████████████▏     |  ETA: 0:00:02 (26.58 ms/it)
# Processing files:  89%|████████████████████████████████████████████▋     |  ETA: 0:00:02 (26.56 ms/it)
# Processing files:  90%|█████████████████████████████████████████████     |  ETA: 0:00:02 (26.51 ms/it)
# Processing files:  91%|█████████████████████████████████████████████▍    |  ETA: 0:00:02 (26.46 ms/it)
# Processing files:  92%|█████████████████████████████████████████████▉    |  ETA: 0:00:01 (26.42 ms/it)
# Processing files:  92%|██████████████████████████████████████████████▎   |  ETA: 0:00:01 (26.39 ms/it)
# Processing files:  93%|██████████████████████████████████████████████▌   |  ETA: 0:00:01 (26.44 ms/it)
# Processing files:  94%|██████████████████████████████████████████████▉   |  ETA: 0:00:01 (26.48 ms/it)
# Processing files:  95%|███████████████████████████████████████████████▋  |  ETA: 0:00:01 (26.49 ms/it)
# Processing files:  96%|████████████████████████████████████████████████  |  ETA: 0:00:01 (26.52 ms/it)
# Processing files:  97%|████████████████████████████████████████████████▎ |  ETA: 0:00:01 (26.68 ms/it)
# Processing files:  98%|█████████████████████████████████████████████████ |  ETA: 0:00:00 (26.77 ms/it)
# Processing files:  99%|█████████████████████████████████████████████████▎|  ETA: 0:00:00 (26.84 ms/it)
# Processing files:  99%|█████████████████████████████████████████████████▌|  ETA: 0:00:00 (26.89 ms/it)
# Processing files:  99%|█████████████████████████████████████████████████▊|  ETA: 0:00:00 (26.98 ms/it)
# Processing files: 100%|██████████████████████████████████████████████████| Time: 0:00:17 (26.95 ms/it)
# ✓ File processing complete! Combining results...
# ✓ Data combination complete!
# Final data size: 28320979 cells, 7 variables
# Creating Table from 28320979 cells with max 4 threads...
#   Threading: 4 threads for 11 columns
#   Max threads requested: 4
#   Available threads: 4
#   Using parallel processing with 4 threads
#   Creating IndexedTable with 11 columns...
# ✓ Table created in 39.647 seconds
# Memory used for data table :2.321086215786636
#  GB
# -------------------------------------------------------

# %%
# current status
# "nothing" allows the functions to use the passed argument: 
# show_progress=false/true
showprogress()
# Out:
# showprogress_mode: nothing

# %%
# switch off the progressbar globally:
showprogress(false)
# Out:
# false

# %%
# check
showprogress()
# Out:
# showprogress_mode: false

# %%
gas = gethydro(info);
# Out:
# [Mera]: Get hydro data: 2026-08-03T11:41:31.204
#
# Key vars=(:level, :cx, :cy, :cz)
# Using var(s)=(1, 2, 3, 4, 5, 6, 7) = (:rho, :vx, :vy, :vz, :p, :scalar_00, :scalar_01)
#
# domain:
# xmin::xmax: 0.0 :: 1.0  	==> 0.0 [kpc] :: 48.0 [kpc]
# ymin::ymax: 0.0 :: 1.0  	==> 0.0 [kpc] :: 48.0 [kpc]
# zmin::zmax: 0.0 :: 1.0  	==> 0.0 [kpc] :: 48.0 [kpc]
#
# 📊 Processing Configuration:
#    Total CPU files available: 640
#    Files to be processed: 640
#    Compute threads: 4
#    GC threads: 4
# ✓ Data combination complete!
# Final data size: 28320979 cells, 7 variables
# Creating Table from 28320979 cells with max 4 threads...
#   Threading: 4 threads for 11 columns
#   Max threads requested: 4
#   Available threads: 4
#   Using parallel processing with 4 threads
#   Creating IndexedTable with 11 columns...
# ✓ Table created in 39.553 seconds
# Memory used for data table :2.321086215786636 GB
# -------------------------------------------------------

# %%
# switch on the progressbar globally:
# the passed argument show_progress=false/true to the individual
# functions is ignored.
showprogress(true)
# Out:
# true

# %%
# check
showprogress()
# Out:
# showprogress_mode: true

# %%
# return to neutral mode
showprogress(nothing)

# %%
# check
showprogress()
# Out:
# showprogress_mode: nothing

# %% [markdown]
# ## Notification Bell

# %%
?bell
# Out:
# search:
# bell real ceil Real fill help all kill
#   bell(sound = nothing)
#
#   Play a short notification sound — e.g. when a long calculation finishes.
#
#   Pick the sound in any of these ways (first match wins):
#
#     1. by name — bell(:chime) (a Symbol or String);
#     2. by number — bell(2) (the position shown by bell(:list), also a
#        numeric string like bell("2"));
#     3. a configured default — [bell] sound = "gong" in ~/.mera.toml, the
#        MERA_BELL_SOUND environment variable, or the legacy ~/bell.txt
#        (see mera_config);
#     4. the built-in fallback — :strum (the original Mera sound).
#
#   19 sounds ship with Mera. List them with their numbers using bell(:list):
#   arpeggio, bell, bird, bloop, bongo, chime, coin, coindrop, cosmic, ding,
#   done, door, frog, gong, knock, oscillations, owl, strum, whistle.
#
#   You can also drop your own *.wav into the package's src/sounds/ folder and
#   select it by its file name or number.
#
#   bell()            # the configured default, else :strum
#   bell(:gong)       # a deep blooming gong
#   bell("chime")     # a glassy three-note chime
#   bell(4)           # the 4th sound in bell(:list)
#   bell(:list)       # print the numbered catalogue of available sounds

# %% [markdown]
# ## Notification E-Mail

# %%
?notifyme
# Out:
# search: notifyme notify mtime time @time ctime
#   Get an email and/or Zulip notification, e.g., when your calculations are
#   finished.
#   ––––––––––––––––––––––––––––
#
#   Both channels are configured in ~/.mera.toml. Print a template with
#   mera_config_example, fill in the parts you want, then chmod 600 ~/.mera.toml
#   — it holds an API key. Configure either channel, or both; each is used only
#   if present.
#
#   [email]
#   to = "you@example.com"
#
#   [zulip]
#   bot_email = "mybot@zulip.example.com"
#   api_key   = "..."                        # or set MERA_ZULIP_API_KEY instead
#   server    = "https://zulip.example.com"
#
#   Email additionally needs the command-line mail client installed; Mera pipes
#   the message to it. Nothing is sent if [email] to is unset.
#
#   Zulip needs all three keys. It is the richer channel: it carries image and
#   file attachments, and posts to a channel/topic (zulip_channel=,
#   zulip_topic=), which email does not.
#
#   Every value can also come from an environment variable — MERA_EMAIL_TO,
#   MERA_ZULIP_BOT_EMAIL, MERA_ZULIP_API_KEY, MERA_ZULIP_SERVER,
#   MERA_ZULIP_CHANNEL — which take precedence over the file and keep secrets
#   off disk. The legacy email.txt, zulip.txt and bell.txt in $HOME still work;
#   ~/.mera.toml wins where both exist. See mera_config.
#
#   Output Capture (optional):
#
#     •  capture_output: Can be a Cmd, Function, or String to capture
#        terminal/function output
#     •  The captured output will be appended to your message
#
#   File Attachments (optional):
#
#     •  image_path: Single image file to attach
#     •  attachments: Vector of file paths to attach (multiple files)
#     •  attachment_folder: Path to folder - all image files (.png, .jpg,
#        .jpeg, .gif, .svg) will be attached
#     •  maxattachments: Maximum number of files to attach when using
#        attachmentfolder (default: 10)
#     •  maxfilesize: Maximum file size in bytes for non-image attachments
#        (default: 25000000 ≈ 25 MB). Files larger than this are skipped
#        with an explanatory warning (Zulip itself may enforce stricter
#        limits – typical defaults are 25–50 MB). For images a stricter 1
#        MB optimization target is applied automatically to keep uploads
#        fast and reliable; large images are resized down to <=1024px on
#        the longest side.
#
#   Time Tracking (optional):
#
#     •  start_time: Start time for execution tracking (use time() or now())
#     •  include_timing: Boolean to include automatic timing information
#        (default: false)
#     •  timing_details: Include detailed performance metrics (memory,
#        allocations)
#
#   Exception Handling (optional):
#
#     •  exception_context: Exception object to include stack trace and
#        error details
#     •  includestacktrace: Boolean to include full stack trace (default:
#        true when exceptioncontext provided)
#
#   julia> notifyme()
#
#   julia> notifyme("Calculation 1 finished!")
#
#   julia> notifyme(msg="Calculation finished!", zulip_channel="alerts", zulip_topic="Run Status")
#
#   julia> notifyme(msg="Plot ready!", zulip_channel="plots", zulip_topic="Results", image_path="result.png")
#
#   julia> notifyme(msg="Multiple results!", attachments=["plot1.png", "plot2.png", "data.csv"])
#
#   julia> notifyme(msg="All plots from analysis!", attachment_folder="./plots/")
#
#   julia> notifyme(msg="Limited plots!", attachment_folder="./plots/", max_attachments=5)
#
#   julia> notifyme(msg="Large dataset results!", attachments=["data.csv"], max_file_size=50_000_000)  # 50MB limit
#
#   # Example: enforce a tighter 5 MB limit to avoid heavy uploads when on slow networks
#   julia> notifyme(msg="Quick summary only", attachments=["summary.log"], max_file_size=5_000_000)
#
#   # Time tracking examples
#   julia> start = time(); heavy_computation(); notifyme("Computation done!", start_time=start)
#
#   julia> notifyme("Analysis finished!", include_timing=true, timing_details=true)
#
#   # Exception handling examples
#   julia> try
#              risky_computation()
#          catch e
#              notifyme("Computation failed!", exception_context=e)
#          end
#
#   julia> notifyme(msg="Directory listing:", capture_output=`ls`)
#
#   julia> notifyme(msg="Function output:", capture_output=() -> sum(rand(100)))
