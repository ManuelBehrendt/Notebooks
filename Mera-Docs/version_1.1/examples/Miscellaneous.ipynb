# %% [markdown]
# # Miscellaneous

# %%
using Mera
info=getinfo(300, "/Volumes/FASTStorage/Simulations/Mera-Tests/mw_L10/", verbose=false);

# %% [markdown]
# ## MyArguments

# %% [markdown]
# Pass several arguments at once to a function for better readability!

# %%
# create an empty struct for arguments:
myargs = ArgumentsType()
# Out:
# ArgumentsType(missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing, missing)

# %%
viewfields(myargs)
# Out:
# [Mera]: Fields to use as arguments in functions
# =======================================================================
# pxsize
# 	= missing
# res	= missing
# lmax	= missing
# xrange	= missing
# yrange	= missing
# zrange	= missing
# radius	= missing
# height	= missing
# direction	= missing
# plane	= missing
# plane_ranges	= missing
# thickness	= missing
# position	= missing
# center	= missing
# range_unit	= missing
# data_center	= missing
# data_center_unit	= missing
# verbose	= missing
# show_progress	= missing
# verbose_threads	= missing

# %%
# assign necessary fields:
myargs.pxsize = [100., :pc]
myargs.xrange=[-10.,10.]
myargs.yrange=[-10.,10.]
myargs.zrange=[-2.,2.]
myargs.center=[:boxcenter]
myargs.range_unit=:kpc;

# %% [markdown]
# <div class="alert alert-block alert-info"> <b>NOTE</b> All functions that hold the upper listed arguments can handle the ArgumentsType struct! </div>

# %%
gas = gethydro(info, myargs=myargs);
# Out:
# [Mera]: Get hydro data: 2026-06-01T18:51:26.187
# Key vars=(:level, :cx, :cy, :cz)
# Using var(s)=(1, 2, 3, 4, 5, 6, 7) = (:rho, :vx, :vy, :vz, :p, :var6, :var7)
# center: [0.5, 0.5, 0.5]
# ==> [24.0 [kpc] :: 24.0 [kpc] :: 24.0 [kpc]]
#
# domain:
# xmin::xmax: 0.2916667 :: 0.7083333  	==> 14.0 [kpc] :: 34.0 [kpc]
# ymin::ymax: 0.2916667 :: 0.7083333  	==> 14.0 [kpc] :: 34.0 [kpc]
# zmin::zmax: 0.4583333 :: 0.5416667  	==> 22.0 [kpc] :: 26.0 [kpc]
#
# 📊 Processing Configuration:
#    Total CPU files available: 640
#    Files to be processed: 640
#    Compute threads: 4
#    GC threads: 4
# Processing files:   0%|                                                  |  ETA: N/A (  N/A  s/it)
# Processing files:   2%|█▏                                                |  ETA: 0:00:35 (56.42 ms/it)
# Processing files:   3%|█▍                                                |  ETA: 0:00:34 (54.03 ms/it)
# Processing files:   3%|█▋                                                |  ETA: 0:00:32 (51.28 ms/it)
# Processing files:   4%|█▉                                                |  ETA: 0:00:30 (49.27 ms/it)
# Processing files:   4%|██▏                                               |  ETA: 0:00:29 (47.59 ms/it)
# Processing files:   5%|██▍                                               |  ETA: 0:00:27 (45.09 ms/it)
# Processing files:   5%|██▊                                               |  ETA: 0:00:26 (43.09 ms/it)
# Processing files:   6%|███▏                                              |  ETA: 0:00:24 (40.26 ms/it)
# Processing files:   7%|███▌                                              |  ETA: 0:00:23 (39.03 ms/it)
# Processing files:   8%|███▊                                              |  ETA: 0:00:23 (38.67 ms/it)
# Processing files:   8%|████▏                                             |  ETA: 0:00:22 (37.49 ms/it)
# Processing files:   9%|████▋                                             |  ETA: 0:00:21 (35.87 ms/it)
# Processing files:  10%|█████                                             |  ETA: 0:00:20 (34.65 ms/it)
# Processing files:  11%|█████▍                                            |  ETA: 0:00:20 (34.44 ms/it)
# Processing files:  12%|██████                                            |  ETA: 0:00:19 (34.11 ms/it)
# Processing files:  13%|██████▌                                           |  ETA: 0:00:18 (32.86 ms/it)
# Processing files:  14%|███████                                           |  ETA: 0:00:18 (32.37 ms/it)
# Processing files:  15%|███████▎                                          |  ETA: 0:00:18 (32.06 ms/it)
# Processing files:  15%|███████▋                                          |  ETA: 0:00:17 (31.79 ms/it)
# Processing files:  16%|████████                                          |  ETA: 0:00:17 (31.34 ms/it)
# Processing files:  17%|████████▎                                         |  ETA: 0:00:17 (31.19 ms/it)
# Processing files:  17%|████████▋                                         |  ETA: 0:00:17 (31.33 ms/it)
# Processing files:  18%|█████████                                         |  ETA: 0:00:16 (31.04 ms/it)
# Processing files:  19%|█████████▍                                        |  ETA: 0:00:16 (30.62 ms/it)
# Processing files:  20%|█████████▉                                        |  ETA: 0:00:16 (30.33 ms/it)
# Processing files:  21%|██████████▌                                       |  ETA: 0:00:15 (29.66 ms/it)
# Processing files:  22%|███████████▏                                      |  ETA: 0:00:14 (29.07 ms/it)
# Processing files:  23%|███████████▊                                      |  ETA: 0:00:14 (28.96 ms/it)
# Processing files:  25%|████████████▍                                     |  ETA: 0:00:14 (28.44 ms/it)
# Processing files:  26%|████████████▉                                     |  ETA: 0:00:13 (27.88 ms/it)
# Processing files:  27%|█████████████▌                                    |  ETA: 0:00:13 (27.52 ms/it)
# Processing files:  28%|█████████████▉                                    |  ETA: 0:00:13 (27.44 ms/it)
# Processing files:  28%|██████████████▎                                   |  ETA: 0:00:13 (27.62 ms/it)
# Processing files:  31%|███████████████▍                                  |  ETA: 0:00:12 (26.85 ms/it)
# Processing files:  32%|███████████████▉                                  |  ETA: 0:00:12 (26.87 ms/it)
# Processing files:  33%|████████████████▍                                 |  ETA: 0:00:11 (26.66 ms/it)
# Processing files:  34%|████████████████▉                                 |  ETA: 0:00:11 (26.39 ms/it)
# Processing files:  35%|█████████████████▎                                |  ETA: 0:00:11 (26.25 ms/it)
# Processing files:  35%|█████████████████▋                                |  ETA: 0:00:11 (26.43 ms/it)
# Processing files:  37%|██████████████████▋                               |  ETA: 0:00:11 (26.39 ms/it)
# Processing files:  38%|██████████████████▉                               |  ETA: 0:00:11 (26.39 ms/it)
# Processing files:  39%|███████████████████▎                              |  ETA: 0:00:10 (26.27 ms/it)
# Processing files:  39%|███████████████████▊                              |  ETA: 0:00:10 (26.15 ms/it)
# Processing files:  40%|████████████████████▏                             |  ETA: 0:00:10 (26.35 ms/it)
# Processing files:  42%|█████████████████████                             |  ETA: 0:00:10 (26.23 ms/it)
# Processing files:  42%|█████████████████████▎                            |  ETA: 0:00:10 (26.34 ms/it)
# Processing files:  43%|█████████████████████▌                            |  ETA: 0:00:10 (26.45 ms/it)
# Processing files:  44%|█████████████████████▊                            |  ETA: 0:00:10 (26.57 ms/it)
# Processing files:  44%|██████████████████████▎                           |  ETA: 0:00:09 (26.67 ms/it)
# Processing files:  45%|██████████████████████▍                           |  ETA: 0:00:09 (26.77 ms/it)
# Processing files:  45%|██████████████████████▊                           |  ETA: 0:00:09 (26.76 ms/it)
# Processing files:  46%|███████████████████████                           |  ETA: 0:00:09 (26.88 ms/it)
# Processing files:  47%|███████████████████████▎                          |  ETA: 0:00:09 (27.03 ms/it)
# Processing files:  47%|███████████████████████▌                          |  ETA: 0:00:09 (27.12 ms/it)
# Processing files:  48%|███████████████████████▉                          |  ETA: 0:00:09 (27.29 ms/it)
# Processing files:  48%|████████████████████████▏                         |  ETA: 0:00:09 (27.41 ms/it)
# Processing files:  49%|████████████████████████▍                         |  ETA: 0:00:09 (27.57 ms/it)
# Processing files:  49%|████████████████████████▋                         |  ETA: 0:00:09 (27.83 ms/it)
# Processing files:  50%|████████████████████████▉                         |  ETA: 0:00:09 (27.98 ms/it)
# Processing files:  50%|█████████████████████████▎                        |  ETA: 0:00:09 (27.98 ms/it)
# Processing files:  51%|█████████████████████████▌                        |  ETA: 0:00:09 (28.08 ms/it)
# Processing files:  52%|█████████████████████████▉                        |  ETA: 0:00:09 (28.14 ms/it)
# Processing files:  53%|██████████████████████████▍                       |  ETA: 0:00:09 (28.14 ms/it)
# Processing files:  53%|██████████████████████████▋                       |  ETA: 0:00:08 (28.19 ms/it)
# Processing files:  54%|███████████████████████████                       |  ETA: 0:00:08 (28.16 ms/it)
# Processing files:  55%|███████████████████████████▎                      |  ETA: 0:00:08 (28.16 ms/it)
# Processing files:  55%|███████████████████████████▋                      |  ETA: 0:00:08 (28.16 ms/it)
# Processing files:  56%|████████████████████████████                      |  ETA: 0:00:08 (28.23 ms/it)
# Processing files:  59%|█████████████████████████████▌                    |  ETA: 0:00:07 (28.02 ms/it)
# Processing files:  60%|█████████████████████████████▉                    |  ETA: 0:00:07 (27.99 ms/it)
# Processing files:  61%|██████████████████████████████▍                   |  ETA: 0:00:07 (27.83 ms/it)
# Processing files:  62%|██████████████████████████████▊                   |  ETA: 0:00:07 (27.82 ms/it)
# Processing files:  62%|███████████████████████████████▏                  |  ETA: 0:00:07 (27.82 ms/it)
# Processing files:  63%|███████████████████████████████▍                  |  ETA: 0:00:07 (27.87 ms/it)
# Processing files:  64%|███████████████████████████████▉                  |  ETA: 0:00:06 (27.73 ms/it)
# Processing files:  65%|████████████████████████████████▍                 |  ETA: 0:00:06 (27.68 ms/it)
# Processing files:  65%|████████████████████████████████▊                 |  ETA: 0:00:06 (27.59 ms/it)
# Processing files:  66%|█████████████████████████████████▎                |  ETA: 0:00:06 (27.55 ms/it)
# Processing files:  68%|█████████████████████████████████▊                |  ETA: 0:00:06 (27.39 ms/it)
# Processing files:  68%|██████████████████████████████████▎               |  ETA: 0:00:06 (27.31 ms/it)
# Processing files:  69%|██████████████████████████████████▊               |  ETA: 0:00:05 (27.18 ms/it)
# Processing files:  70%|███████████████████████████████████▏              |  ETA: 0:00:05 (27.14 ms/it)
# Processing files:  71%|███████████████████████████████████▌              |  ETA: 0:00:05 (27.19 ms/it)
# Processing files:  72%|████████████████████████████████████              |  ETA: 0:00:05 (27.08 ms/it)
# Processing files:  73%|████████████████████████████████████▍             |  ETA: 0:00:05 (27.03 ms/it)
# Processing files:  74%|█████████████████████████████████████             |  ETA: 0:00:04 (26.89 ms/it)
# Processing files:  75%|█████████████████████████████████████▋            |  ETA: 0:00:04 (26.83 ms/it)
# Processing files:  76%|██████████████████████████████████████▎           |  ETA: 0:00:04 (26.67 ms/it)
# Processing files:  77%|██████████████████████████████████████▋           |  ETA: 0:00:04 (26.57 ms/it)
# Processing files:  78%|███████████████████████████████████████▏          |  ETA: 0:00:04 (26.56 ms/it)
# Processing files:  79%|███████████████████████████████████████▌          |  ETA: 0:00:04 (26.62 ms/it)
# Processing files:  80%|████████████████████████████████████████▏         |  ETA: 0:00:03 (26.51 ms/it)
# Processing files:  81%|████████████████████████████████████████▌         |  ETA: 0:00:03 (26.48 ms/it)
# Processing files:  82%|█████████████████████████████████████████         |  ETA: 0:00:03 (26.45 ms/it)
# Processing files:  83%|█████████████████████████████████████████▍        |  ETA: 0:00:03 (26.43 ms/it)
# Processing files:  84%|█████████████████████████████████████████▊        |  ETA: 0:00:03 (26.38 ms/it)
# Processing files:  84%|██████████████████████████████████████████▎       |  ETA: 0:00:03 (26.37 ms/it)
# Processing files:  85%|██████████████████████████████████████████▌       |  ETA: 0:00:03 (26.37 ms/it)
# Processing files:  86%|██████████████████████████████████████████▉       |  ETA: 0:00:02 (26.35 ms/it)
# Processing files:  87%|███████████████████████████████████████████▎      |  ETA: 0:00:02 (26.47 ms/it)
# Processing files:  87%|███████████████████████████████████████████▋      |  ETA: 0:00:02 (26.47 ms/it)
# Processing files:  88%|████████████████████████████████████████████▏     |  ETA: 0:00:02 (26.37 ms/it)
# Processing files:  89%|████████████████████████████████████████████▌     |  ETA: 0:00:02 (26.39 ms/it)
# Processing files:  90%|████████████████████████████████████████████▉     |  ETA: 0:00:02 (26.36 ms/it)
# Processing files:  91%|█████████████████████████████████████████████▎    |  ETA: 0:00:02 (26.35 ms/it)
# Processing files:  91%|█████████████████████████████████████████████▊    |  ETA: 0:00:01 (26.31 ms/it)
# Processing files:  92%|██████████████████████████████████████████████▏   |  ETA: 0:00:01 (26.31 ms/it)
# Processing files:  93%|██████████████████████████████████████████████▍   |  ETA: 0:00:01 (26.41 ms/it)
# Processing files:  96%|████████████████████████████████████████████████  |  ETA: 0:00:01 (26.68 ms/it)
# Processing files:  96%|████████████████████████████████████████████████▎ |  ETA: 0:00:01 (26.74 ms/it)
# Processing files:  97%|████████████████████████████████████████████████▌ |  ETA: 0:00:01 (26.79 ms/it)
# Processing files:  98%|█████████████████████████████████████████████████ |  ETA: 0:00:00 (26.81 ms/it)
# Processing files:  99%|█████████████████████████████████████████████████▎|  ETA: 0:00:00 (26.87 ms/it)
# Processing files:  99%|█████████████████████████████████████████████████▌|  ETA: 0:00:00 (27.04 ms/it)
# Processing files:  99%|█████████████████████████████████████████████████▉|  ETA: 0:00:00 (27.19 ms/it)
# Processing files: 100%|██████████████████████████████████████████████████| Time: 0:00:17 (27.37 ms/it)
# ✓ File processing complete! Combining results...
# ✓ Data combination complete!
# Final data size: 6914359 cells, 7 variables
# Creating Table from 6914359 cells with max 4 threads...
#   Threading: 4 threads for 11 columns
#   Max threads requested: 4
#   Available threads: 4
#   Using parallel processing with 4 threads
#   Creating IndexedTable with 11 columns...
#   9.477106 seconds (250.23 M allocations: 14.027 GiB, 8.35% gc time, 9.43% compilation time)
# ✓ Table created in 9.741 seconds
# Memory used for data table :
# 580.2772397994995 MB
# -------------------------------------------------------

# %%
part = getparticles(info, myargs=myargs);
# Out:
# [Mera]: Get particle data: 2026-06-01T18:51:57.580
# Using threaded processing with 4 threads
# Key vars=(:level, :x, :y, :z, :id, :family, :tag)
# Using var(s)=(1, 2, 3, 4, 7) = (:vx, :vy, :vz, :mass, :birth)
#
# center: [0.5, 0.5, 0.5] ==> [24.0 [kpc] :: 24.0 [kpc] :: 24.0 [kpc]]
#
# domain:
# xmin::xmax: 0.2916667 :: 0.7083333  	==> 14.0 [kpc] :: 34.0 [kpc]
# ymin::ymax: 0.2916667 :: 0.7083333  	==> 14.0 [kpc] :: 34.0 [kpc]
# zmin::zmax: 0.4583333 :: 0.5416667  	==> 22.0 [kpc] :: 26.0 [kpc]
#
# Processing 640 CPU files using 4 threads
# Mode: Threaded processing
# Combining results from 4 thread(s)...
# Found 5.368130e+05 particles
# Memory used for data table :
# 37.885175704956055 MB
# -------------------------------------------------------

# %%
p = projection(gas, :sd, :Msun_pc2, myargs=myargs);
# Out:
# [Mera]: 2026-06-01T18:52:02.766
# center: [0.5, 0.5, 0.5] ==> [24.0 [kpc] :: 24.0 [kpc] :: 24.0 [kpc]]
#
# domain:
# xmin::xmax: 0.2916667 :: 0.7083333  	==> 14.0 [kpc] :: 34.0 [kpc]
# ymin::ymax: 0.2916667 :: 0.7083333  	==> 14.0 [kpc] :: 34.0 [kpc]
# zmin::zmax: 0.4583333 :: 0.5416667  	==> 22.0 [kpc] :: 26.0 [kpc]
#
# Selected var(s)=(:sd,)
# Weighting      = :mass
#
# Effective resolution: 481^2
# Map size: 201 x 201
# Pixel size: 99.792 [pc]
# Simulation min.: 46.875 [pc]
#
# Available threads: 4
# Requested max_threads: 4
# Variables: 1 (sd)
# Processing mode: Sequential (single thread)

# %%
# add more args for silent screen:
myargs.verbose=false
myargs.show_progress=false;

# %%
gas = gethydro(info, myargs=myargs);
# Out:
#   8.941163 seconds (245.97 M allocations: 13.829 GiB, 10.35% gc time)

# %%
part = getparticles(info, myargs=myargs);

# %%
p = projection(gas, :sd, :Msun_pc2, myargs=myargs);

# %% [markdown]
# ## Verbose & Progressbar Switch
# Master switch to toggle the verbose mode and progress bar for all functions:

# %%
# current status
# "nothing" allows the functions to use the passed argument: 
# verbose=false/true
verbose()
# Out:
# verbose_mode: nothing

# %%
# switch off verbose mode globally:
verbose(false)
# Out:
# false

# %%
# check
gas = gethydro(info);
# Out:
# Processing files:   0%|▏                                                 |  ETA: 0:00:45 (70.06 ms/it)
# Processing files:   1%|▌                                                 |  ETA: 0:00:38 (59.64 ms/it)
# Processing files:   2%|█                                                 |  ETA: 0:00:28 (44.19 ms/it)
# Processing files:   3%|█▍                                                |  ETA: 0:00:26 (41.90 ms/it)
# Processing files:   3%|█▋                                                |  ETA: 0:00:26 (42.02 ms/it)
# Processing files:   5%|██▋                                               |  ETA: 0:00:24 (39.81 ms/it)
# Processing files:   6%|███                                               |  ETA: 0:00:23 (38.08 ms/it)
# Processing files:   7%|███▌                                              |  ETA: 0:00:22 (36.34 ms/it)
# Processing files:   8%|███▉                                              |  ETA: 0:00:21 (34.73 ms/it)
# Processing files:   8%|████▎                                             |  ETA: 0:00:20 (33.60 ms/it)
# Processing files:   9%|████▋                                             |  ETA: 0:00:19 (32.58 ms/it)
# Processing files:  10%|█████                                             |  ETA: 0:00:18 (31.81 ms/it)
# Processing files:  11%|█████▎                                            |  ETA: 0:00:18 (31.66 ms/it)
# Processing files:  12%|█████▊                                            |  ETA: 0:00:18 (31.72 ms/it)
# Processing files:  12%|██████▎                                           |  ETA: 0:00:17 (30.82 ms/it)
# Processing files:  13%|██████▊                                           |  ETA: 0:00:17 (30.60 ms/it)
# Processing files:  15%|███████▊                                          |  ETA: 0:00:16 (29.49 ms/it)
# Processing files:  17%|████████▎                                         |  ETA: 0:00:15 (28.99 ms/it)
# Processing files:  17%|████████▋                                         |  ETA: 0:00:15 (28.63 ms/it)
# Processing files:  18%|█████████▏                                        |  ETA: 0:00:15 (28.45 ms/it)
# Processing files:  20%|█████████▉                                        |  ETA: 0:00:15 (28.54 ms/it)
# Processing files:  21%|██████████▍                                       |  ETA: 0:00:14 (28.01 ms/it)
# Processing files:  22%|███████████                                       |  ETA: 0:00:14 (27.38 ms/it)
# Processing files:  23%|███████████▍                                      |  ETA: 0:00:13 (27.18 ms/it)
# Processing files:  24%|████████████                                      |  ETA: 0:00:13 (26.94 ms/it)
# Processing files:  25%|████████████▍                                     |  ETA: 0:00:13 (26.59 ms/it)
# Processing files:  26%|████████████▉                                     |  ETA: 0:00:13 (26.43 ms/it)
# Processing files:  27%|█████████████▌                                    |  ETA: 0:00:12 (25.94 ms/it)
# Processing files:  28%|██████████████                                    |  ETA: 0:00:12 (25.64 ms/it)
# Processing files:  29%|██████████████▌                                   |  ETA: 0:00:12 (25.66 ms/it)
# Processing files:  30%|██████████████▉                                   |  ETA: 0:00:11 (25.43 ms/it)
# Processing files:  31%|███████████████▍                                  |  ETA: 0:00:11 (25.42 ms/it)
# Processing files:  32%|████████████████                                  |  ETA: 0:00:11 (25.19 ms/it)
# Processing files:  32%|████████████████▎                                 |  ETA: 0:00:11 (25.51 ms/it)
# Processing files:  34%|████████████████▊                                 |  ETA: 0:00:11 (25.29 ms/it)
# Processing files:  34%|█████████████████▎                                |  ETA: 0:00:11 (25.48 ms/it)
# Processing files:  36%|██████████████████                                |  ETA: 0:00:10 (25.27 ms/it)
# Processing files:  37%|██████████████████▍                               |  ETA: 0:00:10 (25.24 ms/it)
# Processing files:  37%|██████████████████▋                               |  ETA: 0:00:10 (25.28 ms/it)
# Processing files:  38%|███████████████████                               |  ETA: 0:00:10 (25.39 ms/it)
# Processing files:  39%|███████████████████▍                              |  ETA: 0:00:10 (25.34 ms/it)
# Processing files:  40%|███████████████████▊                              |  ETA: 0:00:10 (25.24 ms/it)
# Processing files:  40%|████████████████████▏                             |  ETA: 0:00:10 (25.29 ms/it)
# Processing files:  41%|████████████████████▍                             |  ETA: 0:00:10 (25.33 ms/it)
# Processing files:  41%|████████████████████▊                             |  ETA: 0:00:10 (25.53 ms/it)
# Processing files:  42%|█████████████████████                             |  ETA: 0:00:10 (25.63 ms/it)
# Processing files:  42%|█████████████████████▏                            |  ETA: 0:00:09 (25.73 ms/it)
# Processing files:  43%|█████████████████████▌                            |  ETA: 0:00:09 (25.73 ms/it)
# Processing files:  43%|█████████████████████▊                            |  ETA: 0:00:09 (25.85 ms/it)
# Processing files:  44%|██████████████████████▏                           |  ETA: 0:00:09 (25.82 ms/it)
# Processing files:  45%|██████████████████████▍                           |  ETA: 0:00:09 (25.95 ms/it)
# Processing files:  45%|██████████████████████▊                           |  ETA: 0:00:09 (26.20 ms/it)
# Processing files:  47%|███████████████████████▋                          |  ETA: 0:00:09 (26.53 ms/it)
# Processing files:  48%|███████████████████████▉                          |  ETA: 0:00:09 (26.64 ms/it)
# Processing files:  48%|████████████████████████                          |  ETA: 0:00:09 (26.78 ms/it)
# Processing files:  49%|████████████████████████▎                         |  ETA: 0:00:09 (26.95 ms/it)
# Processing files:  49%|████████████████████████▌                         |  ETA: 0:00:09 (27.12 ms/it)
# Processing files:  49%|████████████████████████▋                         |  ETA: 0:00:09 (27.33 ms/it)
# Processing files:  50%|████████████████████████▉                         |  ETA: 0:00:09 (27.44 ms/it)
# Processing files:  50%|█████████████████████████▏                        |  ETA: 0:00:09 (27.60 ms/it)
# Processing files:  51%|█████████████████████████▍                        |  ETA: 0:00:09 (27.58 ms/it)
# Processing files:  51%|█████████████████████████▊                        |  ETA: 0:00:09 (27.68 ms/it)
# Processing files:  52%|██████████████████████████                        |  ETA: 0:00:09 (27.74 ms/it)
# Processing files:  52%|██████████████████████████▏                       |  ETA: 0:00:08 (27.84 ms/it)
# Processing files:  53%|██████████████████████████▍                       |  ETA: 0:00:08 (28.00 ms/it)
# Processing files:  53%|██████████████████████████▊                       |  ETA: 0:00:08 (27.98 ms/it)
# Processing files:  54%|███████████████████████████                       |  ETA: 0:00:08 (28.40 ms/it)
# Processing files:  55%|███████████████████████████▍                      |  ETA: 0:00:08 (28.40 ms/it)
# Processing files:  55%|███████████████████████████▋                      |  ETA: 0:00:08 (28.66 ms/it)
# Processing files:  55%|███████████████████████████▊                      |  ETA: 0:00:08 (28.87 ms/it)
# Processing files:  57%|████████████████████████████▌                     |  ETA: 0:00:08 (28.75 ms/it)
# Processing files:  58%|████████████████████████████▉                     |  ETA: 0:00:08 (28.75 ms/it)
# Processing files:  58%|█████████████████████████████▎                    |  ETA: 0:00:08 (28.77 ms/it)
# Processing files:  59%|█████████████████████████████▋                    |  ETA: 0:00:08 (28.74 ms/it)
# Processing files:  60%|██████████████████████████████▏                   |  ETA: 0:00:07 (28.61 ms/it)
# Processing files:  61%|██████████████████████████████▌                   |  ETA: 0:00:07 (28.63 ms/it)
# Processing files:  62%|██████████████████████████████▉                   |  ETA: 0:00:07 (28.55 ms/it)
# Processing files:  62%|███████████████████████████████▎                  |  ETA: 0:00:07 (28.49 ms/it)
# Processing files:  63%|███████████████████████████████▌                  |  ETA: 0:00:07 (28.63 ms/it)
# Processing files:  64%|███████████████████████████████▊                  |  ETA: 0:00:07 (28.67 ms/it)
# Processing files:  64%|████████████████████████████████▎                 |  ETA: 0:00:07 (28.63 ms/it)
# Processing files:  65%|████████████████████████████████▋                 |  ETA: 0:00:06 (28.49 ms/it)
# Processing files:  66%|█████████████████████████████████                 |  ETA: 0:00:06 (28.55 ms/it)
# Processing files:  67%|█████████████████████████████████▍                |  ETA: 0:00:06 (28.55 ms/it)
# Processing files:  68%|█████████████████████████████████▊                |  ETA: 0:00:06 (28.50 ms/it)
# Processing files:  69%|██████████████████████████████████▎               |  ETA: 0:00:06 (28.30 ms/it)
# Processing files:  70%|██████████████████████████████████▊               |  ETA: 0:00:05 (28.20 ms/it)
# Processing files:  70%|███████████████████████████████████▎              |  ETA: 0:00:05 (28.16 ms/it)
# Processing files:  71%|███████████████████████████████████▊              |  ETA: 0:00:05 (28.01 ms/it)
# Processing files:  72%|████████████████████████████████████▏             |  ETA: 0:00:05 (27.96 ms/it)
# Processing files:  74%|████████████████████████████████████▊             |  ETA: 0:00:05 (27.86 ms/it)
# Processing files:  75%|█████████████████████████████████████▌            |  ETA: 0:00:04 (27.63 ms/it)
# Processing files:  76%|██████████████████████████████████████            |  ETA: 0:00:04 (27.67 ms/it)
# Processing files:  77%|██████████████████████████████████████▌           |  ETA: 0:00:04 (27.56 ms/it)
# Processing files:  78%|██████████████████████████████████████▉           |  ETA: 0:00:04 (27.50 ms/it)
# Processing files:  79%|███████████████████████████████████████▎          |  ETA: 0:00:04 (27.46 ms/it)
# Processing files:  80%|███████████████████████████████████████▉          |  ETA: 0:00:04 (27.33 ms/it)
# Processing files:  81%|████████████████████████████████████████▎         |  ETA: 0:00:03 (27.22 ms/it)
# Processing files:  82%|████████████████████████████████████████▊         |  ETA: 0:00:03 (27.21 ms/it)
# Processing files:  82%|█████████████████████████████████████████▎        |  ETA: 0:00:03 (27.13 ms/it)
# Processing files:  83%|█████████████████████████████████████████▋        |  ETA: 0:00:03 (27.12 ms/it)
# Processing files:  84%|██████████████████████████████████████████        |  ETA: 0:00:03 (27.13 ms/it)
# Processing files:  85%|██████████████████████████████████████████▎       |  ETA: 0:00:03 (27.12 ms/it)
# Processing files:  85%|██████████████████████████████████████████▊       |  ETA: 0:00:03 (27.01 ms/it)
# Processing files:  86%|███████████████████████████████████████████▎      |  ETA: 0:00:02 (26.97 ms/it)
# Processing files:  87%|███████████████████████████████████████████▋      |  ETA: 0:00:02 (26.91 ms/it)
# Processing files:  88%|████████████████████████████████████████████      |  ETA: 0:00:02 (26.94 ms/it)
# Processing files:  89%|████████████████████████████████████████████▌     |  ETA: 0:00:02 (26.84 ms/it)
# Processing files:  90%|█████████████████████████████████████████████     |  ETA: 0:00:02 (26.95 ms/it)
# Processing files:  91%|█████████████████████████████████████████████▌    |  ETA: 0:00:02 (26.87 ms/it)
# Processing files:  92%|█████████████████████████████████████████████▉    |  ETA: 0:00:01 (26.83 ms/it)
# Processing files:  92%|██████████████████████████████████████████████▎   |  ETA: 0:00:01 (26.83 ms/it)
# Processing files:  93%|██████████████████████████████████████████████▌   |  ETA: 0:00:01 (26.83 ms/it)
# Processing files:  94%|██████████████████████████████████████████████▉   |  ETA: 0:00:01 (26.84 ms/it)
# Processing files:  94%|███████████████████████████████████████████████▎  |  ETA: 0:00:01 (26.93 ms/it)
# Processing files:  96%|███████████████████████████████████████████████▉  |  ETA: 0:00:01 (26.85 ms/it)
# Processing files:  97%|████████████████████████████████████████████████▎ |  ETA: 0:00:01 (26.90 ms/it)
# Processing files:  97%|████████████████████████████████████████████████▋ |  ETA: 0:00:00 (27.00 ms/it)
# Processing files:  98%|█████████████████████████████████████████████████▏|  ETA: 0:00:00 (27.11 ms/it)
# Processing files:  99%|█████████████████████████████████████████████████▍|  ETA: 0:00:00 (27.14 ms/it)
# Processing files:  99%|█████████████████████████████████████████████████▋|  ETA: 0:00:00 (27.40 ms/it)
# Processing files: 100%|██████████████████████████████████████████████████| Time: 0:00:17 (27.70 ms/it)
# ✓ File processing complete! Combining results...
#  39.691495 seconds (958.14 M allocations: 55.370 GiB, 8.84% gc time)

# %%
# switch on verbose mode globally:
# the passed argument verbose=false/true to the individual
# functions is ignored.
verbose(true)
# Out:
# true

# %%
gas = gethydro(info);
# Out:
# [Mera]: Get hydro data: 2026-06-01T18:53:32.408
#
# Key vars=(:level, :cx, :cy, :cz)
# Using var(s)=(1, 2, 3, 4, 5, 6, 7) = (:rho, :vx, :vy, :vz, :p, :var6, :var7)
#
# domain:
# xmin::xmax: 0.0 :: 1.0  	==> 0.0 [kpc] :: 48.0 [kpc]
# ymin::ymax: 0.0 :: 1.0  	==> 0.0 [kpc] :: 48.0 [kpc]
# zmin::zmax: 0.0 :: 1.0  	==> 0.0 [kpc] :: 48.0 [kpc]
#
# 📊 Processing Configuration:
#    Total CPU files available: 640
#    Files to be processed: 640
#    Compute threads: 4
#    GC threads: 4
# Processing files:   0%|                                                  |  ETA: N/A (  N/A  s/it)
# Processing files:   1%|▍                                                 |  ETA: 0:00:37 (58.43 ms/it)
# Processing files:   1%|▋                                                 |  ETA: 0:00:31 (49.24 ms/it)
# Processing files:   2%|▉                                                 |  ETA: 0:00:29 (46.56 ms/it)
# Processing files:   2%|█▏                                                |  ETA: 0:00:26 (41.30 ms/it)
# Processing files:   3%|█▌                                                |  ETA: 0:00:24 (38.03 ms/it)
# Processing files:   3%|█▊                                                |  ETA: 0:00:23 (37.90 ms/it)
# Processing files:   4%|██▏                                               |  ETA: 0:00:23 (37.08 ms/it)
# Processing files:   5%|██▍                                               |  ETA: 0:00:22 (36.77 ms/it)
# Processing files:   5%|██▋                                               |  ETA: 0:00:24 (39.69 ms/it)
# Processing files:   6%|███                                               |  ETA: 0:00:23 (38.79 ms/it)
# Processing files:   8%|███▉                                              |  ETA: 0:00:21 (34.94 ms/it)
# Processing files:   9%|████▎                                             |  ETA: 0:00:19 (33.06 ms/it)
# Processing files:   9%|████▊                                             |  ETA: 0:00:19 (32.55 ms/it)
# Processing files:  10%|█████                                             |  ETA: 0:00:19 (32.13 ms/it)
# Processing files:  11%|█████▌                                            |  ETA: 0:00:18 (31.00 ms/it)
# Processing files:  12%|█████▊                                            |  ETA: 0:00:17 (30.71 ms/it)
# Processing files:  12%|██████▏                                           |  ETA: 0:00:17 (30.25 ms/it)
# Processing files:  13%|██████▊                                           |  ETA: 0:00:16 (29.63 ms/it)
# Processing files:  14%|███████▎                                          |  ETA: 0:00:16 (28.85 ms/it)
# Processing files:  15%|███████▋                                          |  ETA: 0:00:15 (28.53 ms/it)
# Processing files:  16%|████████                                          |  ETA: 0:00:15 (28.45 ms/it)
# Processing files:  17%|████████▌                                         |  ETA: 0:00:15 (27.87 ms/it)
# Processing files:  18%|████████▉                                         |  ETA: 0:00:15 (27.91 ms/it)
# Processing files:  18%|█████████▎                                        |  ETA: 0:00:15 (27.93 ms/it)
# Processing files:  19%|█████████▋                                        |  ETA: 0:00:14 (27.62 ms/it)
# Processing files:  20%|██████████▏                                       |  ETA: 0:00:14 (27.25 ms/it)
# Processing files:  21%|██████████▌                                       |  ETA: 0:00:14 (27.01 ms/it)
# Processing files:  22%|███████████                                       |  ETA: 0:00:13 (26.59 ms/it)
# Processing files:  23%|███████████▌                                      |  ETA: 0:00:13 (26.45 ms/it)
# Processing files:  24%|████████████                                      |  ETA: 0:00:13 (25.91 ms/it)
# Processing files:  25%|████████████▌                                     |  ETA: 0:00:12 (25.72 ms/it)
# Processing files:  26%|█████████████                                     |  ETA: 0:00:12 (25.62 ms/it)
# Processing files:  27%|█████████████▍                                    |  ETA: 0:00:12 (25.48 ms/it)
# Processing files:  28%|█████████████▉                                    |  ETA: 0:00:12 (25.22 ms/it)
# Processing files:  29%|██████████████▌                                   |  ETA: 0:00:11 (24.83 ms/it)
# Processing files:  30%|███████████████                                   |  ETA: 0:00:11 (25.64 ms/it)
# Processing files:  31%|███████████████▍                                  |  ETA: 0:00:11 (25.52 ms/it)
# Processing files:  32%|███████████████▉                                  |  ETA: 0:00:11 (25.29 ms/it)
# Processing files:  33%|████████████████▍                                 |  ETA: 0:00:11 (25.35 ms/it)
# Processing files:  34%|████████████████▊                                 |  ETA: 0:00:11 (25.17 ms/it)
# Processing files:  34%|█████████████████▎                                |  ETA: 0:00:11 (25.33 ms/it)
# Processing files:  36%|█████████████████▉                                |  ETA: 0:00:10 (25.24 ms/it)
# Processing files:  36%|██████████████████▎                               |  ETA: 0:00:10 (25.24 ms/it)
# Processing files:  37%|██████████████████▋                               |  ETA: 0:00:10 (25.13 ms/it)
# Processing files:  38%|███████████████████                               |  ETA: 0:00:10 (25.19 ms/it)
# Processing files:  39%|███████████████████▍                              |  ETA: 0:00:10 (25.25 ms/it)
# Processing files:  40%|███████████████████▊                              |  ETA: 0:00:10 (25.23 ms/it)
# Processing files:  40%|████████████████████▏                             |  ETA: 0:00:10 (25.29 ms/it)
# Processing files:  41%|████████████████████▌                             |  ETA: 0:00:10 (25.42 ms/it)
# Processing files:  45%|██████████████████████▍                           |  ETA: 0:00:09 (25.83 ms/it)
# Processing files:  45%|██████████████████████▋                           |  ETA: 0:00:09 (25.99 ms/it)
# Processing files:  46%|███████████████████████                           |  ETA: 0:00:09 (26.00 ms/it)
# Processing files:  47%|███████████████████████▎                          |  ETA: 0:00:09 (26.33 ms/it)
# Processing files:  47%|███████████████████████▌                          |  ETA: 0:00:09 (26.45 ms/it)
# Processing files:  48%|███████████████████████▊                          |  ETA: 0:00:09 (26.89 ms/it)
# Processing files:  48%|███████████████████████▉                          |  ETA: 0:00:09 (27.10 ms/it)
# Processing files:  49%|████████████████████████▊                         |  ETA: 0:00:09 (27.37 ms/it)
# Processing files:  50%|████████████████████████▉                         |  ETA: 0:00:09 (27.65 ms/it)
# Processing files:  51%|█████████████████████████▌                        |  ETA: 0:00:09 (27.64 ms/it)
# Processing files:  52%|█████████████████████████▊                        |  ETA: 0:00:09 (27.89 ms/it)
# Processing files:  52%|██████████████████████████▏                       |  ETA: 0:00:09 (27.89 ms/it)
# Processing files:  53%|██████████████████████████▍                       |  ETA: 0:00:08 (27.97 ms/it)
# Processing files:  53%|██████████████████████████▋                       |  ETA: 0:00:08 (28.15 ms/it)
# Processing files:  54%|██████████████████████████▉                       |  ETA: 0:00:08 (28.23 ms/it)
# Processing files:  54%|███████████████████████████                       |  ETA: 0:00:08 (28.39 ms/it)
# Processing files:  55%|███████████████████████████▋                      |  ETA: 0:00:08 (28.53 ms/it)
# Processing files:  56%|███████████████████████████▉                      |  ETA: 0:00:08 (28.53 ms/it)
# Processing files:  56%|████████████████████████████▏                     |  ETA: 0:00:08 (28.62 ms/it)
# Processing files:  57%|████████████████████████████▌                     |  ETA: 0:00:08 (28.64 ms/it)
# Processing files:  58%|████████████████████████████▊                     |  ETA: 0:00:08 (28.60 ms/it)
# Processing files:  58%|█████████████████████████████                     |  ETA: 0:00:08 (28.57 ms/it)
# Processing files:  59%|█████████████████████████████▌                    |  ETA: 0:00:08 (28.55 ms/it)
# Processing files:  60%|█████████████████████████████▊                    |  ETA: 0:00:07 (28.53 ms/it)
# Processing files:  60%|██████████████████████████████▏                   |  ETA: 0:00:07 (28.44 ms/it)
# Processing files:  61%|██████████████████████████████▌                   |  ETA: 0:00:07 (28.43 ms/it)
# Processing files:  62%|███████████████████████████████                   |  ETA: 0:00:07 (28.39 ms/it)
# Processing files:  62%|███████████████████████████████▏                  |  ETA: 0:00:07 (28.44 ms/it)
# Processing files:  64%|███████████████████████████████▉                  |  ETA: 0:00:07 (28.27 ms/it)
# Processing files:  65%|████████████████████████████████▎                 |  ETA: 0:00:06 (28.22 ms/it)
# Processing files:  65%|████████████████████████████████▋                 |  ETA: 0:00:06 (28.17 ms/it)
# Processing files:  66%|█████████████████████████████████                 |  ETA: 0:00:06 (28.20 ms/it)
# Processing files:  67%|█████████████████████████████████▍                |  ETA: 0:00:06 (28.13 ms/it)
# Processing files:  68%|█████████████████████████████████▊                |  ETA: 0:00:06 (28.11 ms/it)
# Processing files:  68%|██████████████████████████████████▎               |  ETA: 0:00:06 (28.01 ms/it)
# Processing files:  69%|██████████████████████████████████▋               |  ETA: 0:00:06 (27.93 ms/it)
# Processing files:  70%|███████████████████████████████████▏              |  ETA: 0:00:05 (27.81 ms/it)
# Processing files:  71%|███████████████████████████████████▌              |  ETA: 0:00:05 (27.76 ms/it)
# Processing files:  72%|████████████████████████████████████              |  ETA: 0:00:05 (27.57 ms/it)
# Processing files:  73%|████████████████████████████████████▍             |  ETA: 0:00:05 (27.57 ms/it)
# Processing files:  74%|█████████████████████████████████████             |  ETA: 0:00:05 (27.43 ms/it)
# Processing files:  75%|█████████████████████████████████████▋            |  ETA: 0:00:04 (27.34 ms/it)
# Processing files:  76%|██████████████████████████████████████▏           |  ETA: 0:00:04 (27.18 ms/it)
# Processing files:  77%|██████████████████████████████████████▋           |  ETA: 0:00:04 (27.12 ms/it)
# Processing files:  78%|███████████████████████████████████████           |  ETA: 0:00:04 (27.09 ms/it)
# Processing files:  79%|███████████████████████████████████████▌          |  ETA: 0:00:04 (27.05 ms/it)
# Processing files:  80%|████████████████████████████████████████          |  ETA: 0:00:03 (26.96 ms/it)
# Processing files:  81%|████████████████████████████████████████▌         |  ETA: 0:00:03 (26.81 ms/it)
# Processing files:  82%|█████████████████████████████████████████         |  ETA: 0:00:03 (26.81 ms/it)
# Processing files:  83%|█████████████████████████████████████████▌        |  ETA: 0:00:03 (26.74 ms/it)
# Processing files:  84%|█████████████████████████████████████████▊        |  ETA: 0:00:03 (26.73 ms/it)
# Processing files:  84%|██████████████████████████████████████████▏       |  ETA: 0:00:03 (26.74 ms/it)
# Processing files:  86%|███████████████████████████████████████████▏      |  ETA: 0:00:02 (26.58 ms/it)
# Processing files:  87%|███████████████████████████████████████████▋      |  ETA: 0:00:02 (26.52 ms/it)
# Processing files:  88%|████████████████████████████████████████████      |  ETA: 0:00:02 (26.51 ms/it)
# Processing files:  89%|████████████████████████████████████████████▍     |  ETA: 0:00:02 (26.47 ms/it)
# Processing files:  89%|████████████████████████████████████████████▊     |  ETA: 0:00:02 (26.47 ms/it)
# Processing files:  90%|█████████████████████████████████████████████     |  ETA: 0:00:02 (26.57 ms/it)
# Processing files:  91%|█████████████████████████████████████████████▌    |  ETA: 0:00:02 (26.53 ms/it)
# Processing files:  92%|█████████████████████████████████████████████▉    |  ETA: 0:00:01 (26.49 ms/it)
# Processing files:  92%|██████████████████████████████████████████████▎   |  ETA: 0:00:01 (26.45 ms/it)
# Processing files:  93%|██████████████████████████████████████████████▋   |  ETA: 0:00:01 (26.44 ms/it)
# Processing files:  94%|███████████████████████████████████████████████   |  ETA: 0:00:01 (26.41 ms/it)
# Processing files:  95%|███████████████████████████████████████████████▍  |  ETA: 0:00:01 (26.44 ms/it)
# Processing files:  95%|███████████████████████████████████████████████▊  |  ETA: 0:00:01 (26.46 ms/it)
# Processing files:  96%|████████████████████████████████████████████████▏ |  ETA: 0:00:01 (26.54 ms/it)
# Processing files:  97%|████████████████████████████████████████████████▌ |  ETA: 0:00:01 (26.54 ms/it)
# Processing files:  98%|████████████████████████████████████████████████▉ |  ETA: 0:00:00 (26.60 ms/it)
# Processing files:  98%|█████████████████████████████████████████████████▏|  ETA: 0:00:00 (26.72 ms/it)
# Processing files: 100%|██████████████████████████████████████████████████| Time: 0:00:17 (27.33 ms/it)
# ✓ File processing complete! Combining results...
# ✓ Data combination complete!
# Final data size: 28320979 cells, 7 variables
# Creating Table from 28320979 cells with max 4 threads...
#   Threading: 4 threads for 11 columns
#   Max threads requested: 4
#   Available threads: 4
#   Using parallel processing with 4 threads
#   Creating IndexedTable with 11 columns...
#  39.385238 seconds (958.14 M allocations: 55.369 GiB, 8.70% gc time)
# ✓ Table created in 39.743 seconds
# Memory used for data table :2.321086215786636 GB
# -------------------------------------------------------

# %%
# current status
# "nothing" allows the functions to use the passed argument: 
# show_progress=false/true
showprogress()
# Out:
# showprogress_mode: nothing

# %%
# switch off the progressbar globally:
showprogress(false)
# Out:
# false

# %%
# check
showprogress()
# Out:
# showprogress_mode: false

# %%
gas = gethydro(info);
# Out:
# [Mera]: Get hydro data: 2026-06-01T18:54:30.579
#
# Key vars=(:level, :cx, :cy, :cz)
# Using var(s)=(1, 2, 3, 4, 5, 6, 7) = (:rho, :vx, :vy, :vz, :p, :var6, :var7)
#
# domain:
# xmin::xmax: 0.0 :: 1.0  	==> 0.0 [kpc] :: 48.0 [kpc]
# ymin::ymax: 0.0 :: 1.0  	==> 0.0 [kpc] :: 48.0 [kpc]
# zmin::zmax: 0.0 :: 1.0  	==> 0.0 [kpc] :: 48.0 [kpc]
#
# 📊 Processing Configuration:
#    Total CPU files available: 640
#    Files to be processed: 640
#    Compute threads: 4
#    GC threads: 4
# ✓ Data combination complete!
# Final data size: 28320979 cells, 7 variables
# Creating Table from 28320979 cells with max 4 threads...
#   Threading: 4 threads for 11 columns
#   Max threads requested: 4
#   Available threads: 4
#   Using parallel processing with 4 threads
#   Creating IndexedTable with 11 columns...
#  38.284447 seconds (958.14 M allocations: 55.420 GiB, 9.07% gc time)
# ✓ Table created in 38.556 seconds
# Memory used for data table :2.321086215786636 GB
# -------------------------------------------------------

# %%
# switch on the progressbar globally:
# the passed argument show_progress=false/true to the individual
# functions is ignored.
showprogress(true)
# Out:
# true

# %%
# check
showprogress()
# Out:
# showprogress_mode: true

# %%
# return to neutral mode
showprogress(nothing)

# %%
# check
showprogress()
# Out:
# showprogress_mode: nothing

# %% [markdown]
# ## Notification Bell

# %%
?bell
# Out:
# search:
# bell ceil all Real real fill kill help
#   No documentation found for public binding Mera.bell.
#
#   Mera.bell is a Function.
#
#   # 1 method for generic function "bell" from Mera:
#    [1] bell()
#        @ ~/Documents/codes/github/Mera.jl/src/functions/notifications.jl:11

# %% [markdown]
# ## Notification E-Mail

# %%
?notifyme
# Out:
# search: notifyme notify time ctime @time mtime
#   Get an email and/or Zulip notification, e.g., when your calculations are
#   finished.
#   ––––––––––––––––––––––––––––
#
#   Email notification:
#
#     •  Requires the email client "mail" to be installed
#     •  Put a file with the name "email.txt" in your home folder that
#        contains your email address in the first line
#
#   Zulip notification (optional):
#
#     •  Put a file with the name "zulip.txt" in your home folder with
#        three lines:
#
#        •  Line 1: Your Zulip bot email (e.g.,
#        mybot@zulip.yourdomain.com)
#        •  Line 2: Your Zulip API key
#        •  Line 3: Your Zulip server URL (e.g.,
#        https://zulip.yourdomain.com)
#
#   Output Capture (optional):
#
#     •  capture_output: Can be a Cmd, Function, or String to capture
#        terminal/function output
#     •  The captured output will be appended to your message
#
#   File Attachments (optional):
#
#     •  image_path: Single image file to attach
#     •  attachments: Vector of file paths to attach (multiple files)
#     •  attachment_folder: Path to folder - all image files (.png, .jpg,
#        .jpeg, .gif, .svg) will be attached
#     •  maxattachments: Maximum number of files to attach when using
#        attachmentfolder (default: 10)
#     •  maxfilesize: Maximum file size in bytes for non-image attachments
#        (default: 25000000 ≈ 25 MB). Files larger than this are skipped
#        with an explanatory warning (Zulip itself may enforce stricter
#        limits – typical defaults are 25–50 MB). For images a stricter 1
#        MB optimization target is applied automatically to keep uploads
#        fast and reliable; large images are resized down to <=1024px on
#        the longest side.
#
#   Time Tracking (optional):
#
#     •  start_time: Start time for execution tracking (use time() or now())
#     •  include_timing: Boolean to include automatic timing information
#        (default: false)
#     •  timing_details: Include detailed performance metrics (memory,
#        allocations)
#
#   Exception Handling (optional):
#
#     •  exception_context: Exception object to include stack trace and
#        error details
#     •  includestacktrace: Boolean to include full stack trace (default:
#        true when exceptioncontext provided)
#
#   julia> notifyme()
#
#   julia> notifyme("Calculation 1 finished!")
#
#   julia> notifyme(msg="Calculation finished!", zulip_channel="alerts", zulip_topic="Run Status")
#
#   julia> notifyme(msg="Plot ready!", zulip_channel="plots", zulip_topic="Results", image_path="result.png")
#
#   julia> notifyme(msg="Multiple results!", attachments=["plot1.png", "plot2.png", "data.csv"])
#
#   julia> notifyme(msg="All plots from analysis!", attachment_folder="./plots/")
#
#   julia> notifyme(msg="Limited plots!", attachment_folder="./plots/", max_attachments=5)
#
#   julia> notifyme(msg="Large dataset results!", attachments=["data.csv"], max_file_size=50_000_000)  # 50MB limit
#
#   # Example: enforce a tighter 5 MB limit to avoid heavy uploads when on slow networks
#   julia> notifyme(msg="Quick summary only", attachments=["summary.log"], max_file_size=5_000_000)
#
#   # Time tracking examples
#   julia> start = time(); heavy_computation(); notifyme("Computation done!", start_time=start)
#
#   julia> notifyme("Analysis finished!", include_timing=true, timing_details=true)
#
#   # Exception handling examples
#   julia> try
#              risky_computation()
#          catch e
#              notifyme("Computation failed!", exception_context=e)
#          end
#
#   julia> notifyme(msg="Directory listing:", capture_output=`ls`)
#
#   julia> notifyme(msg="Function output:", capture_output=() -> sum(rand(100)))
